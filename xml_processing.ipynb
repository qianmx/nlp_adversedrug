# %% [markdown]
# https://bionlp.nlm.nih.gov/tac2017adversereactions/

# %% [markdown]
# Task 1: Extract AdverseReactions and related mentions (Severity, Factor, DrugClass, Negation, Animal). This is similar to many NLP Named Entity Recognition (NER) evaluations.

# %%
import untangle
import glob
import pandas as pd
from collections import Counter
import re
import string
import csv

# %%
path = '/Users/jzhu/git/nlp_adversedrug/data/train_xml/'

# %%
def parse_xml(filename):
    """
    @input a filename string
    @return:
    1. For training data: both a dictionary (key is the section) for X (text strings) and a list of dictionary for y 
        (keys: id (not for task 1), section, type, start, len)
    2. For test data: only a list of X
    """
    X = {}
    Y = []
    
    obj = untangle.parse(filename)
    for text in obj.Label.Text.Section:
        X[text['id']] = text.cdata
        
    if obj.Label.Mentions.Mention:
        for mention in obj.Label.Mentions.Mention:
            entity = {}
            entity['id'] = mention['id']
            entity['section'] = mention['section']
            entity['type'] = mention['type']
            entity['start'] = mention['start']
            entity['len'] = mention['len']
            entity['text'] = mention['str']
            Y.append(entity)
            
    return X, Y

def parse_unannotated_xml(filename):
    """
    @input a filename string
    @return:
    1. For training data: both a dictionary (key is the section) for X (text strings) and a list of dictionary for y 
        (keys: id (not for task 1), section, type, start, len)
    2. For test data: only a list of X
    """
    import untangle
    
    X = {}
    
    obj = untangle.parse(filename)
    for text in obj.Label.Text.Section:
        X[text['id']] = text.cdata
            
    return X

# %% [markdown]
# # test

# %%
filename = path + 'ADCETRIS.xml'
X, Y = parse_xml(filename)

# %%
X.keys()
# Out:
# [u'S3', u'S2', u'S1']

# %%
X['S1']
# Out:
# u'    6 ADVERSE REACTIONS\n\n  The following serious adverse reactions are discussed in greater detail in other sections of the prescribing information:\n\n\n\n *  Peripheral Neuropathy [see  Warnings and Precautions (      5.1      )  ]  \n *  Anaphylaxis and Infusion Reactions [see  Warnings and Precautions (      5.2      )  ]  \n *  Hematologic Toxicities [see  Warnings and Precautions (      5.3      )  ]  \n *  Serious Infections and Opportunistic Infections [see  Warnings and Precautions (      5.4      )  ]  \n *  Tumor Lysis Syndrome [see  Warnings and Precautions (      5.5      )  ]  \n *  Increased Toxicity in the Presence of Severe Renal Impairment [see  Warnings and Precautions (      5.6      )  ]  \n *  Increased Toxicity in the Presence of Moderate or Severe Hepatic Impairment [see  Warnings and Precautions (      5.7      )  ]  \n *  Hepatotoxicity [see  Warnings and Precautions (      5.8      )  ]  \n *  Progressive Multifocal Leukoencephalopathy [see  Warnings and Precautions (      5.9      )  ]  \n *  Pulmonary Toxicity [see  Warnings and Precautions (5.10)  ]  \n *  Serious Dermatologic Reactions [see  Warnings and Precautions (5.11)    ]   \n      EXCERPT:   The most common adverse reactions (>=20%) were:\n \n\n *  Relapsed classical HL and relapsed sALCL: neutropenia, peripheral sensory neuropathy, fatigue, nausea, anemia, upper respiratory tract infection, diarrhea, pyrexia, rash, thrombocytopenia, cough, and vomiting  (6.1)  . \n *  Classical HL post-auto-HSCT consolidation: neutropenia, peripheral sensory neuropathy, thrombocytopenia, anemia, upper respiratory tract infection, fatigue, peripheral motor neuropathy, nausea, cough, and diarrhea  (6.1)  . \n      To report SUSPECTED ADVERSE REACTIONS, contact Seattle Genetics, Inc. at 1-855-473-2436 or FDA at 1-800-FDA-1088 or www.fda.gov/medwatch.  \n \n\n \n\n  6.1 Clinical Trial Experience\n\n  Because clinical trials are conducted under widely varying conditions, adverse reaction rates observed in clinical trials of a drug cannot be directly compared to rates in the clinical trials of another drug and may not reflect the rates observed in practice.\n\n\n\n The data below reflect exposure to ADCETRIS as monotherapy in 327 patients with classical Hodgkin lymphoma (HL) and systemic anaplastic large cell lymphoma (sALCL), including 160 patients in two uncontrolled single-arm trials (Studies 1 and 2) and 167 patients in one placebo-controlled randomized trial (Study 3).\n\n\n\n In Studies 1 and 2, the most common adverse reactions (>=20%), regardless of causality, were neutropenia, peripheral sensory neuropathy, fatigue, nausea, anemia, upper respiratory tract infection, diarrhea, pyrexia, rash, thrombocytopenia, cough, and vomiting. The most common adverse reactions occurring in at least 10% of patients in either Study 1 or 2, regardless of causality, using the NCI Common Toxicity Criteria (CTC) Version 3.0, are shown in   Table 2  .\n\n\n\n In Study 3, the most common adverse reactions (>=20%) in the ADCETRIS-treatment arm, regardless of causality, were neutropenia, peripheral sensory neuropathy, thrombocytopenia, anemia, upper respiratory tract infection, fatigue, peripheral motor neuropathy, nausea, cough, and diarrhea. The most common adverse reactions occurring in at least 10% of patients, using the NCI CTC Version 4, are shown in  Table 3  .\n\n\n\n   Experience in Classical Hodgkin Lymphoma  \n\n\n\n     Summary of Clinical Trial Experience in Relapsed Classical HL (Study 1)    \n\n\n\n ADCETRIS was studied in 102 patients with classical HL in a single arm clinical trial in which the recommended starting dose and schedule was 1.8 mg/kg intravenously every 3 weeks. Median duration of treatment was 9 cycles (range, 1-16)  [see  Clinical Studies (        14.1        )  ]  .\n\n\n\n The most common adverse reactions (>=20%), regardless of causality, were neutropenia, peripheral sensory neuropathy, fatigue, upper respiratory tract infection, nausea,  ...

# %%
X['S1'][236:(236+11)]
# Out:
# u'Anaphylaxis'

# %%
Y[:2]
# Out:
# [{'id': u'M1',
#   'len': u'21',
#   'section': u'S1',
#   'start': u'156',
#   'text': u'Peripheral Neuropathy',
#   'type': u'AdverseReaction'},
#  {'id': u'M2',
#   'len': u'11',
#   'section': u'S1',
#   'start': u'236',
#   'text': u'Anaphylaxis',
#   'type': u'AdverseReaction'}]

# %% [markdown]
# ### For NER_DL: extract only the entities and tags in training folder (then use the pre-trained word2vec from spacy)

# %%
f = path + 'ADCETRIS.xml'
X, Y = parse_xml(f)
X.keys()
# Out:
# [u'S3', u'S2', u'S1']

# %%
train = []
ct_good = 0
ct_bad = 0

for f in glob.glob(path+'*.xml'):
    X, Y = parse_xml(f)

    for section in X.keys():
        doc = X[section]
        print f, section
    
        # split the words in a doc
        word_ind = [[m.group(0).lower(), m.start(), m.end(), 'O'] for m in re.finditer(r'\w+', doc)
            if m.group(0) ]
        words = [w[0] for w in word_ind]
        starts = [s[1] for s in word_ind]
        ends = [e[2] for e in word_ind]
        types = [e[3] for e in word_ind]
        start_dict = dict(zip(starts, range(len(starts))))
        end_dict = dict(zip(ends, range(len(ends))))
        

        # parse the names in the same doc
        e_text = []
        e_type = []
        e_start = []
        e_end = []
        for e in Y:
            if e['section'] == section:
                starts = e['start'].split(',')
                lens = e['len'].split(',')
                for i in range(len(starts)):
                    e_text.append(e['text'])
                    e_type.append(e['type'])
                    e_start.append(int(starts[i]))
                    e_end.append(int(starts[i]) + int(lens[i]))

        # label the names in the list of total words
        for i in range(len(e_start)):
            if (e_start[i] in start_dict) and (e_end[i] in end_dict):
                ct_good += 1
                ind_start = start_dict[e_start[i]]
                ind_end = end_dict[e_end[i]]

                words[ind_start] = ' '.join(words[ind_start:(ind_end + 1)])
                types[ind_start] = e_type[i]
                for j in range(ind_start, ind_end):
                    types[j+1] = 'rm' # label to remove later

            else:
                ct_bad += 1
#                 print f, section, e_text[i], e_start[i], e_end[i]
                
        # remove those words tagged with 'rm' (i.e. combine names with more than one word)
        train += [[words[i], types[i]] for i in range(len(words)) if types[i] != 'rm']
        print len(train)

        # insert a new line to seperate from the next section
        train.append([''])
        print len(train)
# Out:
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ADCETRIS.xml S3
# 1021
# 1022
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ADCETRIS.xml S2
# 1080
# 1081
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ADCETRIS.xml S1
# 3307
# 3308
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ADREVIEW.xml S2
# 4130
# 4131
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ADREVIEW.xml S1
# 4430
# 4431
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/AFINITOR.xml S2
# 6102
# 6103
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/AFINITOR.xml S1
# 10335
# 10336
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/AMPYRA.xml S2
# 10853
# 10854
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/AMPYRA.xml S1
# 11324
# 11325
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/AMYVID.xml S2
# 11543
# 11544
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/AMYVID.xml S1
# 11810
# 11811
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/APTIOM.xml S2
# 13836
# 13837
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/APTIOM.xml S1
# 14721
# 14722
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ARCAPTA.xml S3
# 15715
# 15716
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ARCAPTA.xml S2
# 15924
# 15925
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ARCAPTA.xml S1
# 16833
# 16834
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BELEODAQ.xml S2
# 17235
# 17236
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BELEODAQ.xml S1
# 17808
# 17809
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BENLYSTA.xml S2
# 19210
# 19211
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BENLYSTA.xml S1
# 20073
# 20074
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BEPREVE.xml S2
# 20253
# 20254
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BEPREVE.xml S1
# 20451
# 20452
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BESIVANCE.xml S2
# 20631
# 20632
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BESIVANCE.xml S1
# 20786
# 20787
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BLINCYTO.xml S3
# 21521
# 21522
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BLINCYTO.xml S2
# 21651
# 21652
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BLINCYTO.xml S1
# 22573
# 22574
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BOSULIF.xml S2
# 23539
# 23540
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BOSULIF.xml S1
# 24631
# 24632
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BREO.xml S3
# 27339
# 27340
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BREO.xml S2
# 27804
# 27805
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BREO.xml S1
# 29565
# 29566
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CARBAGLU.xml S2
# 29814
# 29815
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CARBAGLU.xml S1
# 30064
# 30065
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CERDELGA.xml S2
# 30283
# 30284
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CERDELGA.xml S1
# 30742
# 30743
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CHOLINE.xml S2
# 31090
# 31091
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CHOLINE.xml S1
# 31156
# 31157
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CIMZIA.xml S3
# 33480
# 33481
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CIMZIA.xml S2
# 33899
# 33900
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CIMZIA.xml S1
# 36085
# 36086
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CLEVIPREX.xml S2
# 36423
# 36424
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CLEVIPREX.xml S1
# 37108
# 37109
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/COARTEM.xml S2
# 38049
# 38050
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/COARTEM.xml S1
# 38969
# 38970
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/COMETRIQ.xml S3
# 39709
# 39710
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/COMETRIQ.xml S2
# 39866
# 39867
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/COMETRIQ.xml S1
# 40943
# 40944
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DALVANCE.xml S2
# 41395
# 41396
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DALVANCE.xml S1
# 41949
# 41950
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DATSCAN.xml S2
# 42176
# 42177
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DATSCAN.xml S1
# 42430
# 42431
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DIFICID.xml S2
# 42619
# 42620
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DIFICID.xml S1
# 42983
# 42984
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DOTAREM.xml S3
# 43628
# 43629
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DOTAREM.xml S2
# 43909
# 43910
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DOTAREM.xml S1
# 44453
# 44454
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DUAVEE.xml S3
# 46188
# 46189
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DUAVEE.xml S2
# 48332
# 48333
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DUAVEE.xml S1
# 48835
# 48836
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DUREZOL.xml S2
# 49439
# 49440
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DUREZOL.xml S1
# 49631
# 49632
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DYSPORT.xml S3
# 50461
# 50462
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DYSPORT.xml S2
# 50703
# 50704
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DYSPORT.xml S1
# 52509
# 52510
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/EDARBI.xml S3
# 52840
# 52841
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/EDARBI.xml S2
# 52905
# 52906
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/EDARBI.xml S1
# 53409
# 53410
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ELIQUIS.xml S3
# 54045
# 54046
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ELIQUIS.xml S2
# 54422
# 54423
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ELIQUIS.xml S1
# 56776
# 56777
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ENTEREG.xml S3
# 57554
# 57555
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ENTEREG.xml S2
# 57767
# 57768
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ENTEREG.xml S1
# 58065
# 58066
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/EOVIST.xml S3
# 58848
# 58849
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/EOVIST.xml S2
# 59126
# 59127
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/EOVIST.xml S1
# 59595
# 59596
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ERWINAZE.xml S2
# 59909
# 59910
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ERWINAZE.xml S1
# 60939
# 60940
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/EYLEA.xml S2
# 61284
# 61285
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/EYLEA.xml S1
# 62121
# 62122
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FANAPT.xml S3
# 65303
# 65304
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FANAPT.xml S2
# 65562
# 65563
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FANAPT.xml S1
# 67131
# 67132
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FARXIGA.xml S2
# 67729
# 67730
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FARXIGA.xml S1
# 70145
# 70146
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FERRIPROX.xml S3
# 70645
# 70646
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FERRIPROX.xml S2
# 70821
# 70822
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FERRIPROX.xml S1
# 71352
# 71353
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FIRAZYR.xml S2
# 71411
# 71412
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FIRAZYR.xml S1
# 71999
# 72000
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FULYZAQ.xml S2
# 72111
# 72112
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FULYZAQ.xml S1
# 72541
# 72542
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/GADAVIST.xml S3
# 73212
# 73213
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/GADAVIST.xml S2
# 73488
# 73489
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/GADAVIST.xml S1
# 73916
# 73917
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/GILENYA.xml S2
# 76313
# 76314
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/GILENYA.xml S1
# 76983
# 76984
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/GILOTRIF.xml S2
# 77896
# 77897
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/GILOTRIF.xml S1
# 78765
# 78766
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/GRANIX.xml S2
# 79143
# 79144
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/GRANIX.xml S1
# 79661
# 79662
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/HALAVEN.xml S2
# 80193
# 80194
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/HALAVEN.xml S1
# 81164
# 81165
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/HORIZANT.xml S2
# 82757
# 82758
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/HORIZANT.xml S1
# 83802
# 83803
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ILARIS.xml S2
# 84600
# 84601
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ILARIS.xml S1
# 86029
# 86030
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/IMBRUVICA.xml S2
# 86568
# 86569
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/IMBRUVICA.xml S1
# 88119
# 88120
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/INLYTA.xml S2
# 89851
# 89852
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/INLYTA.xml S1
# 90625
# 90626
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/INTELENCE.xml S2
# 91005
# 91006
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/INTELENCE.xml S1
# 92709
# 92710
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/INVOKANA.xml S2
# 93346
# 93347
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/INVOKANA.xml S1
# 96521
# 96522
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/JARDIANCE.xml S2
# 96972
# 96973
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/JARDIANCE.xml S1
# 98730
# 98731
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/JEVTANA.xml S3
# 99818
# 99819
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/JEVTANA.xml S2
# 100032
# 100033
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/JEVTANA.xml S1
# 101132
# 101133
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/JUBLIA.xml S1
# 101332
# 101333
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/KALBITOR.xml S3
# 101541
# 101542
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/KALBITOR.xml S2
# 101718
# 101719
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/KALBITOR.xml S1
# 102458
# 102459
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/KALYDECO.xml S2
# 102863
# 102864
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/KALYDECO.xml S1
# 103825
# 103826
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/KYPROLIS.xml S2
# 105204
# 105205
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/KYPROLIS.xml S1
# 107230
# 107231
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/LUMIZYME.xml S3
# 108160
# 108161
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/LUMIZYME.xml S2
# 108458
# 108459
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/LUMIZYME.xml S1
# 110410
# 110411
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/MULTAQ.xml S3
# 111207
# 111208
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/MULTAQ.xml S2
# 111430
# 111431
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/MULTAQ.xml S1
# 111986
# 111987
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NATAZIA.xml S3
# 113403
# 113404
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NATAZIA.xml S2
# 113512
# 113513
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NATAZIA.xml S1
# 114005
# 114006
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NESINA.xml S2
# 114723
# 114724
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NESINA.xml S1
# 115790
# 115791
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NEURACEQ.xml S2
# 116017
# 116018
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NEURACEQ.xml S1
# 116241
# 116242
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NORTHERA.xml S3
# 116526
# 116527
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NORTHERA.xml S2
# 116664
# 116665
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NORTHERA.xml S1
# 117148
# 117149
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NULOJIX.xml S3
# 118411
# 118412
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NULOJIX.xml S2
# 118716
# 118717
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NULOJIX.xml S1
# 121681
# 121682
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ONFI.xml S2
# 122806
# 122807
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ONFI.xml S1
# 123532
# 123533
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/OTEZLA.xml S2
# 124210
# 124211
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/OTEZLA.xml S1
# 125166
# 125167
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PICATO.xml S2
# 125416
# 125417
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PICATO.xml S1
# 126254
# 126255
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/POTIGA.xml S3
# 128240
# 128241
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/POTIGA.xml S2
# 128634
# 128635
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/POTIGA.xml S1
# 129485
# 129486
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PRADAXA.xml S3
# 130410
# 130411
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PRADAXA.xml S2
# 130824
# 130825
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PRADAXA.xml S1
# 132684
# 132685
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PRISTIQ.xml S3
# 134927
# 134928
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PRISTIQ.xml S2
# 135111
# 135112
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PRISTIQ.xml S1
# 136757
# 136758
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PROLIA.xml S2
# 138006
# 138007
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PROLIA.xml S1
# 140369
# 140370
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PROMACTA.xml S3
# 141155
# 141156
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PROMACTA.xml S2
# 141244
# 141245
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PROMACTA.xml S1
# 142503
# 142504
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/QUTENZA.xml S2
# 142959
# 142960
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/QUTENZA.xml S1
# 143441
# 143442
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/SAPHRIS.xml S3
# 148183
# 148184
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/SAPHRIS.xml S2
# 148293
# 148294
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/SAPHRIS.xml S1
# 151995
# 151996
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/SIMPONI.xml S3
# 154274
# 154275
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/SIMPONI.xml S2
# 154671
# 154672
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/SIMPONI.xml S1
# 156009
# 156010
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/SIRTURO.xml S3
# 156640
# 156641
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/SIRTURO.xml S2
# 156842
# 156843
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/SIRTURO.xml S1
# 157487
# 157488
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/STENDRA.xml S2
# 158898
# 158899
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/STENDRA.xml S1
# 160057
# 160058
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/STRIBILD.xml S3
# 161620
# 161621
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/STRIBILD.xml S2
# 161900
# 161901
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/STRIBILD.xml S1
# 163473
# 163474
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TAFINLAR.xml S2
# 166165
# 166166
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TAFINLAR.xml S1
# 168221
# 168222
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TANZEUM.xml S3
# 169047
# 169048
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TANZEUM.xml S2
# 169307
# 169308
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TANZEUM.xml S1
# 171235
# 171236
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TECFIDERA.xml S2
# 171991
# 171992
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TECFIDERA.xml S1
# 172514
# 172515
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TEFLARO.xml S2
# 173013
# 173014
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TEFLARO.xml S1
# 173641
# 173642
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TIVICAY.xml S2
# 174123
# 174124
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TIVICAY.xml S1
# 176087
# 176088
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TOVIAZ.xml S2
# 176639
# 176640
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TOVIAZ.xml S1
# 177493
# 177494
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TREANDA.xml S2
# 178333
# 178334
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TREANDA.xml S1
# 179988
# 179989
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TRULICITY.xml S3
# 180822
# 180823
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TRULICITY.xml S2
# 181071
# 181072
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TRULICITY.xml S1
# 182651
# 182652
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TUDORZA.xml S2
# 183054
# 183055
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TUDORZA.xml S1
# 183656
# 183657
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ULESFIA.xml S2
# 183883
# 183884
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ULESFIA.xml S1
# 184189
# 184190
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ULORIC.xml S2
# 184712
# 184713
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ULORIC.xml S1
# 185674
# 185675
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/VICTRELIS.xml S2
# 187221
# 187222
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/VICTRELIS.xml S1
# 188556
# 188557
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/VIMIZIM.xml S3
# 189159
# 189160
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/VIMIZIM.xml S2
# 189412
# 189413
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/VIMIZIM.xml S1
# 190077
# 190078
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/VIZAMYL.xml S2
# 190392
# 190393
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/VIZAMYL.xml S1
# 190617
# 190618
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/VORAXAZE.xml S2
# 190969
# 190970
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/VORAXAZE.xml S1
# 192125
# 192126
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/XALKORI.xml S2
# 193162
# 193163
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/XALKORI.xml S1
# 194996
# 194997
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/XEOMIN.xml S3
# 196069
# 196070
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/XEOMIN.xml S2
# 196302
# 196303
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/XEOMIN.xml S1
# 197439
# 197440
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/XIAFLEX.xml S3
# 198499
# 198500
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/XIAFLEX.xml S2
# 198786
# 198787
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/XIAFLEX.xml S1
# 201020
# 201021
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/XTANDI.xml S2
# 201298
# 201299
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/XTANDI.xml S1
# 202757
# 202758
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/YERVOY.xml S3
# 204492
# 204493
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/YERVOY.xml S2
# 204750
# 204751
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/YERVOY.xml S1
# 205572
# 205573
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ZERBAXA.xml S2
# 206068
# 206069
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ZERBAXA.xml S1
# 206809
# 206810
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ZYDELIG.xml S3
# 207530
# 207531
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ZYDELIG.xml S2
# 207831
# 207832
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ZYDELIG.xml S1
# 208885
# 208886
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ZYKADIA.xml S2
# 210227
# 210228
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ZYKADIA.xml S1
# 210882
# 210883
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ZYTIGA.xml S2
# 211648
# 211649
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ZYTIGA.xml S1
# 213036
# 213037

# %%
print ct_good, ct_bad, ct_bad * 1.0 /ct_good
# Out:
# 16728 128 0.00765184122429

# %%
len(train)
# Out:
# 213037

# %%
for i in train[1020:1030]:
    print i
# Out:
# [u'1', 'O']
# ['']
# [u'boxed', 'O']
# [u'warning', 'O']
# [u'warning', 'O']
# [u'progressive multifocal leukoencephalopathy', u'AdverseReaction']
# [u'pml', u'AdverseReaction']
# [u'warning', 'O']
# [u'progressive multifocal leukoencephalopathy', u'AdverseReaction']
# [u'pml', u'AdverseReaction']

# %%
213037 - 212798 # num of sections of all xml files
# Out:
# 239

# %%
with open("train.csv", "wb") as f:
    writer = csv.writer(f)
    writer.writerows(train)

# %% [markdown]
# Note:
# * Since the name index is based on original text, we cannot do word labeling one word by one word.
# * Thus I first wrote all words in sentences one in a line, with the index on the same line
# * then use the name index from xml to relabel those types of names
# * Only 0.7% names are not found in the processed train.csv. So I am fine with that. Most of them are due to hard to seperated words such as "decreasedSOD"

# %% [markdown]
# # Process unannotated dataset

# %%
testpath = '/Users/jzhu/git/nlp_adversedrug/data/unannotated_xml/'

# %%
test = []
ct = 1

for f in glob.glob(testpath + '*.xml'):
    filename = f.split('/')[-1].split('.')[0]
    print "Processing:", filename
    X = parse_unannotated_xml(f)

    for section in X.keys():
        doc = X[section]
    
        # split the words in a doc
        word_ind = [[filename, section, m.group(0).lower(), m.start(), m.end()] 
                    for m in re.finditer(r'\w+', doc) if m.group(0)]
        test.extend(word_ind)
# Out:
# Processing: 8MOP
# Processing: ABELCET
# Processing: ABILIFY0
# Processing: ABILIFY1
# Processing: ABILIFY2
# Processing: ABIRATERONE
# Processing: ABRAXANE
# Processing: ABSORICA
# Processing: ABSTRAL
# Processing: ACANYA
# Processing: ACCURETIC
# Processing: ACEON
# Processing: ACETADOTE
# Processing: ACIPHEX0
# Processing: ACIPHEX1
# Processing: ACTEMRA
# Processing: ACTHIB
# Processing: ACTHREL
# Processing: ACTICLATE
# Processing: ACTIVELLA
# Processing: ACTOPLUS0
# Processing: ACTOPLUS1
# Processing: ACULAR0
# Processing: ACULAR1
# Processing: ACUVAIL
# Processing: ACZONE0
# Processing: ACZONE1
# Processing: ADACEL
# Processing: ADAGEN
# Processing: ADAPALENE
# Processing: ADASUVE
# Processing: ADCETRIS
# Processing: ADCIRCA
# Processing: ADDYI
# Processing: ADEMPAS
# Processing: ADENOCARD
# Processing: ADENOSCAN
# Processing: ADENOVIRUS
# Processing: ADLYXIN
# Processing: ADRENALIN
# Processing: ADREVIEW
# Processing: ADULT0
# Processing: ADULT1
# Processing: ADVAIR0
# Processing: ADVAIR1
# Processing: ADVATE
# Processing: ADYNOVATE
# Processing: ADZENYS
# Processing: AEROSPAN
# Processing: AFINITOR
# Processing: AFLURIA
# Processing: AFREZZA
# Processing: AFSTYLA
# Processing: AGGRASTAT
# Processing: AGRYLIN
# Processing: AKFLUOR
# Processing: AKOVAZ
# Processing: AKTEN
# Processing: AKYNZEO
# Processing: ALBENZA
# Processing: ALBUKED
# Processing: ALBUMIN
# Processing: ALBUMINAR5
# Processing: ALBURX
# Processing: ALBUTEIN
# Processing: ALBUTEROL
# Processing: ALDACTONE
# Processing: ALDARA
# Processing: ALECENSA
# Processing: ALFENTA
# Processing: ALIMTA
# Processing: ALINIA
# Processing: ALKERAN0
# Processing: ALKERAN1
# Processing: ALLEGRA
# Processing: ALLERGEN0
# Processing: ALLERGEN1
# Processing: ALLOCORD
# Processing: ALOCRIL
# Processing: ALOGLIPTIN
# Processing: ALOMIDE
# Processing: ALOPRIM
# Processing: ALOXI
# Processing: ALPHAGAN
# Processing: ALPHANATE
# Processing: ALPHANINE
# Processing: ALPRAZOLAM0
# Processing: ALPRAZOLAM1
# Processing: ALPROLIX
# Processing: ALREX
# Processing: ALTABAX
# Processing: ALTACE
# Processing: ALTOPREV
# Processing: ALVESCO
# Processing: AMARYL
# Processing: AMBIEN
# Processing: AMBISOME
# Processing: AMELUZ
# Processing: AMERGE
# Processing: AMICAR
# Processing: AMIDATE
# Processing: AMIFOSTINE
# Processing: AMINOCAPROIC
# Processing: AMITIZA
# Processing: AMLODIPINE0
# Processing: AMLODIPINE1
# Processing: AMLODIPINE2
# Processing: AMMONIA
# Processing: AMPHADASE
# Processing: AMPYRA
# Processing: AMRIX
# Processing: AMYVID
# Processing: ANADROL50
# Processing: ANAFRANIL
# Processing: ANASCORP
# Processing: ANCOBON
# Processing: ANDRODERM
# Processing: ANDROGEL0
# Processing: ANDROGEL1
# Processing: ANECTINE
# Processing: ANGELIQ
# Processing: ANORO
# Processing: ANTARA
# Processing: ANTHRASIL
# Processing: ANTICOAGULANT1
# Processing: ANTIVENIN0
# Processing: ANTIVENIN1
# Processing: ANTIZOL
# Processing: ANZEMET
# Processing: APIDRA
# Processing: APLENZIN
# Processing: APLISOL
# Processing: APOKYN
# Processing: APPLE
# Processing: APRACLONIDINE
# Processing: APRISO
# Processing: APTENSIO
# Processing: APTIOM
# Processing: APTIVUS
# Processing: AQUASOL
# Processing: ARALAST
# Processing: ARCALYST
# Processing: ARCAPTA
# Processing: ARESTIN
# Processing: ARGATROBAN
# Processing: ARGATROBAN0
# Processing: ARGATROBAN1
# Processing: ARICEPT
# Processing: ARIMIDEX
# Processing: ARISTADA
# Processing: ARISTOSPAN
# Processing: ARNUITY
# Processing: ARRANON
# Processing: ARTHROTEC
# Processing: ARTICAINE
# Processing: ARTISS
# Processing: ARYMO
# Processing: ARZERRA
# Processing: ASACOL
# Processing: ASCLERA
# Processing: ASMANEX0
# Processing: ASMANEX1
# Processing: ASPIRIN
# Processing: ASTAGRAF
# Processing: ATACAND0
# Processing: ATACAND1
# Processing: ATELVIA
# Processing: ATGAM
# Processing: ATIVAN
# Processing: ATOVAQUONE
# Processing: ATRALIN
# Processing: ATRIDOX
# Processing: ATRIPLA
# Processing: ATROPEN
# Processing: ATROPINE0
# Processing: ATROPINE1
# Processing: ATROVENT0
# Processing: ATROVENT1
# Processing: ATROVENT2
# Processing: ATRYN
# Processing: AUBAGIO
# Processing: AUGMENTIN
# Processing: AUGMENTINXR
# Processing: AURYXIA
# Processing: AUVIQ
# Processing: AVAGE
# Processing: AVALIDE
# Processing: AVANDAMET
# Processing: AVANDIA
# Processing: AVAPRO
# Processing: AVC
# Processing: AVEED
# Processing: AVELOX
# Processing: AVODART
# Processing: AVYCAZ
# Processing: AXERT
# Processing: AXIRON
# Processing: AXUMIN
# Processing: AZACTAM0
# Processing: AZACTAM1
# Processing: AZASITE
# Processing: AZELASTINE0
# Processing: AZELASTINE1
# Processing: AZELEX
# Processing: AZILECT
# Processing: AZITHROMYCIN0
# Processing: AZITHROMYCIN1
# Processing: AZOPT
# Processing: BABYBIG
# Processing: BACTERIOSTATIC
# Processing: BACTRIM
# Processing: BACTROBAN0
# Processing: BACTROBAN1
# Processing: BAL
# Processing: BANZEL
# Processing: BARACLUDE
# Processing: BAT
# Processing: BCG
# Processing: BEBULIN
# Processing: BECONASE
# Processing: BELBUCA
# Processing: BELEODAQ
# Processing: BELSOMRA
# Processing: BELVIQ
# Processing: BENDEKA
# Processing: BENEFIX
# Processing: BENICAR
# Processing: BENTYL
# Processing: BENZACLIN
# Processing: BENZTROPINE
# Processing: BEPREVE
# Processing: BERINERT
# Processing: BERMUDA
# Processing: BESIVANCE
# Processing: BETADINE
# Processing: BETAGAN
# Processing: BETAMETHASONE0
# Processing: BETAMETHASONE1
# Processing: BETAMETHASONE2
# Processing: BETAPACE
# Processing: BETAXOLOL
# Processing: BETHKIS
# Processing: BETIMOL
# Processing: BETOPTIC
# Processing: BEVESPI
# Processing: BEXSERO
# Processing: BIAXIN0
# Processing: BIAXIN1
# Processing: BICILLIN0
# Processing: BICILLIN1
# Processing: BICNU
# Processing: BIDIL
# Processing: BILTRICIDE
# Processing: BINOSTO
# Processing: BIOTHRAX
# Processing: BIVALIRUDIN
# Processing: BIVIGAM
# Processing: BLEPHAMIDE
# Processing: BLOXIVERZ
# Processing: BONIVA0
# Processing: BONIVA1
# Processing: BOOSTRIX
# Processing: BOSULIF
# Processing: BRAVELLE
# Processing: BREO
# Processing: BREVITAL
# Processing: BRIDION
# Processing: BRILINTA
# Processing: BRIMONIDINE
# Processing: BRINTELLIX
# Processing: BRISDELLE
# Processing: BRIVIACT
# Processing: BROMDAY
# Processing: BROMOCRIPTINE
# Processing: BROMSITE
# Processing: BROVANA
# Processing: BSS0
# Processing: BSS1
# Processing: BUMINATE
# Processing: BUNAVAIL
# Processing: BUPHENYL
# Processing: BUPIVACAINE
# Processing: BUPRENEX
# Processing: BUSULFEX
# Processing: BUTALBITAL0
# Processing: BUTALBITAL1
# Processing: BUTALBITAL2
# Processing: BUTISOL
# Processing: BUTRANS
# Processing: BYDUREON
# Processing: BYETTA
# Processing: BYSTOLIC
# Processing: CABERGOLINE
# Processing: CABOMETYX
# Processing: CAFCIT
# Processing: CALAN
# Processing: CALCIPOTRIENE
# Processing: CALCIPOTRIENE0
# Processing: CALCIPOTRIENE1
# Processing: CALCITONIN
# Processing: CALCITRIOL
# Processing: CALCIUM0
# Processing: CALCIUM1
# Processing: CALCIUM2
# Processing: CALDOLOR
# Processing: CAMBIA
# Processing: CAMPRAL
# Processing: CAMPTOSAR
# Processing: CAMRESE
# Processing: CANASA
# Processing: CANCIDAS
# Processing: CANDIN
# Processing: CANTIL
# Processing: CAPASTAT
# Processing: CAPEX
# Processing: CAPRELSA
# Processing: CARAC
# Processing: CARAFATE
# Processing: CARBAGLU
# Processing: CARBAMAZEPINE0
# Processing: CARBAMAZEPINE1
# Processing: CARBIDOPA0
# Processing: CARBIDOPA1
# Processing: CARBOCAINE
# Processing: CARDENE
# Processing: CARDIOLITE
# Processing: CARDIZEM0
# Processing: CARDIZEM1
# Processing: CARDIZEM2
# Processing: CARDURA
# Processing: CARIMUNE
# Processing: CARNEXIV
# Processing: CARNITOR
# Processing: CARTICEL
# Processing: CASODEX
# Processing: CAT0
# Processing: CAT1
# Processing: CAT2
# Processing: CATAPRES0
# Processing: CATAPRES1
# Processing: CATTLE
# Processing: CAVERJECT
# Processing: CAYSTON
# Processing: CEFAZOLIN
# Processing: CEFEPIME
# Processing: CEFOTETAN
# Processing: CEFOXITIN
# Processing: CEFTAZIDIME
# Processing: CEFTIN
# Processing: CEFTRIAXONE
# Processing: CELEBREX
# Processing: CELESTONE
# Processing: CELEXA
# Processing: CELLCEPT0
# Processing: CELLCEPT1
# Processing: CELONTIN
# Processing: CEPROTIN
# Processing: CERDELGA
# Processing: CEREBYX
# Processing: CERETEC
# Processing: CEREZYME
# Processing: CESAMET
# Processing: CETROTIDE
# Processing: CETYLEV
# Processing: CHANTIX
# Processing: CHEMET
# Processing: CHIRHOSTIM
# Processing: CHLORAPREP1
# Processing: CHLORDIAZEPOXIDE
# Processing: CHOLBAM
# Processing: CHOLETEC
# Processing: CHOLINE
# Processing: CHORIONIC
# Processing: CHROMIUM
# Processing: CIALIS
# Processing: CICLOPIROX0
# Processing: CICLOPIROX1
# Processing: CILOXAN
# Processing: CINRYZE
# Processing: CIPRO0
# Processing: CIPRO1
# Processing: CIPRO2
# Processing: CIPRODEX
# Processing: CIPROFLOXACIN
# Processing: CITANEST
# Processing: CLARINEX
# Processing: CLARINEXD
# Processing: CLEOCIN0
# Processing: CLEOCIN1
# Processing: CLEOCIN2
# Processing: CLEVIPREX
# Processing: CLIMARA0
# Processing: CLIMARA1
# Processing: CLINDAGEL
# Processing: CLINDAMYCIN
# Processing: CLINDAMYCIN0
# Processing: CLINDAMYCIN1
# Processing: CLINDESSE
# Processing: CLINIMIX
# Processing: CLOBETASOL
# Processing: CLOBETASOL0
# Processing: CLOBETASOL1
# Processing: CLOCORTOLONE
# Processing: CLOLAR
# Processing: CLOMIPHENE
# Processing: CLONIDINE
# Processing: CLOSTRIDIUM
# Processing: CLOZAPINE
# Processing: CLOZARIL
# Processing: COAGADEX
# Processing: COARTEM
# Processing: CODEINE
# Processing: COLAZAL
# Processing: COLCHICINE
# Processing: COLESTID0
# Processing: COLESTID1
# Processing: COLPREP
# Processing: COLYMYCIN
# Processing: COMBIGAN
# Processing: COMBIPATCH
# Processing: COMBIVENT
# Processing: COMBIVIR
# Processing: COMETRIQ
# Processing: COMPLERA
# Processing: CONDYLOX0
# Processing: CONDYLOX1
# Processing: CONRAY0
# Processing: CONRAY1
# Processing: CONTRAVE
# Processing: COPAXONE
# Processing: COPPER
# Processing: CORDCYTE
# Processing: CORDRAN
# Processing: COREG0
# Processing: COREG1
# Processing: CORIFACT
# Processing: CORLANOR
# Processing: CORLOPAM
# Processing: CORTEF
# Processing: CORTIFOAM
# Processing: CORTISPORIN0
# Processing: CORTISPORIN1
# Processing: CORTISPORINTC
# Processing: CORTROSYN
# Processing: CORVERT
# Processing: CORZIDE
# Processing: COSMEGEN
# Processing: COSOPT
# Processing: COTELLIC
# Processing: COUMADIN
# Processing: COZAAR
# Processing: CREON
# Processing: CRESEMBA
# Processing: CRESTOR
# Processing: CRINONE
# Processing: CRIXIVAN
# Processing: CROFAB
# Processing: CUBICIN
# Processing: CUPRIMINE
# Processing: CUROSURF
# Processing: CUTIVATE0
# Processing: CUTIVATE1
# Processing: CUVITRU
# Processing: CUVPOSA
# Processing: CYANOKIT
# Processing: CYCLESSA
# Processing: CYCLOPHOSPHAMIDE
# Processing: CYCLOSET
# Processing: CYKLOKAPRON
# Processing: CYMBALTA
# Processing: CYRAMZA
# Processing: CYSTADANE
# Processing: CYSTAGON
# Processing: CYSTARAN
# Processing: CYSTOGRAFIN
# Processing: CYSVIEW
# Processing: CYTOGAM
# Processing: CYTOMEL
# Processing: CYTOTEC
# Processing: CYTOVENE
# Processing: DACOGEN
# Processing: DAKLINZA
# Processing: DALIRESP
# Processing: DALVANCE
# Processing: DANTRIUM
# Processing: DANTROLENE
# Processing: DAPTACEL
# Processing: DARANIDE
# Processing: DARAPRIM
# Processing: DARIFENACIN
# Processing: DATSCAN
# Processing: DAYPRO
# Processing: DAYTRANA
# Processing: DDAVP0
# Processing: DDAVP1
# Processing: DDAVP2
# Processing: DECITABINE
# Processing: DEFINITY
# Processing: DEFITELIO
# Processing: DELZICOL
# Processing: DEMADEX
# Processing: DEMEROL
# Processing: DEMSER
# Processing: DENAVIR
# Processing: DEPACON
# Processing: DEPAKENE
# Processing: DEPAKOTE0
# Processing: DEPAKOTE1
# Processing: DEPEN
# Processing: DEPOCYT
# Processing: DEPOPROVERA0
# Processing: DEPOPROVERA1
# Processing: DEPOSUBQ
# Processing: DERMACINRX
# Processing: DERMASMOOTHEFS
# Processing: DERMATOP
# Processing: DESCOVY
# Processing: DESFERAL
# Processing: DESMOPRESSIN
# Processing: DESONATE
# Processing: DESONIDE0
# Processing: DESONIDE1
# Processing: DESOXIMETASONE
# Processing: DESOXYN
# Processing: DESVENLAFAXINE
# Processing: DETROL
# Processing: DEXILANT0
# Processing: DEXILANT1
# Processing: DEXMEDETOMIDINE
# Processing: DEXMETHYLPHENIDATE
# Processing: DEXTROAMPHETAMINE0
# Processing: DEXTROAMPHETAMINE1
# Processing: DEXTROSE0
# Processing: DEXTROSE1
# Processing: DEXTROSE10
# Processing: DEXTROSE2
# Processing: DEXTROSE3
# Processing: DEXTROSE4
# Processing: DEXTROSE5
# Processing: DEXTROSE6
# Processing: DEXTROSE7
# Processing: DEXTROSE8
# Processing: DEXTROSE9
# Processing: DHE
# Processing: DIABETA
# Processing: DIAMOX
# Processing: DIAZEPAM
# Processing: DICLEGIS
# Processing: DICLOFENAC
# Processing: DIDREX
# Processing: DIETHYLPROPION
# Processing: DIFFERIN
# Processing: DIFFERIN0
# Processing: DIFICID
# Processing: DIFLUCAN
# Processing: DIGIFAB
# Processing: DIGOXIN
# Processing: DIHYDROERGOTAMINE
# Processing: DILANTIN125
# Processing: DILATRATE
# Processing: DILAUDID
# Processing: DILTIAZEM
# Processing: DINOPROSTONE
# Processing: DIOVAN
# Processing: DIPENTUM
# Processing: DIPHENOXYLATE
# Processing: DIPHTHERIA
# Processing: DIPRIVAN
# Processing: DIPROLENE0
# Processing: DIPROLENE1
# Processing: DIPROLENE2
# Processing: DIPYRIDAMOLE
# Processing: DISKETS
# Processing: DITROPAN
# Processing: DIURIL
# Processing: DIVALPROEX
# Processing: DIVIGEL
# Processing: DOBUTAMINE
# Processing: DOCETAXEL0
# Processing: DOCETAXEL1
# Processing: DOLOPHINE
# Processing: DONEPEZIL
# Processing: DOPAMINE
# Processing: DOPAMINE0
# Processing: DOPAMINE1
# Processing: DOPRAM
# Processing: DORIBAX
# Processing: DORYX
# Processing: DOTAREM
# Processing: DOVONEX
# Processing: DOXAZOSIN
# Processing: DOXEPIN
# Processing: DOXERCALCIFEROL
# Processing: DOXORUBICIN
# Processing: DOXYCYCLINE
# Processing: DOXYCYCLINE0
# Processing: DOXYCYCLINE1
# Processing: DRISDOL
# Processing: DRONABINOL
# Processing: DROSPIRENONEETHINYL
# Processing: DST
# Processing: DUAVEE
# Processing: DUCORD
# Processing: DUEXIS
# Processing: DULERA
# Processing: DUODOTE
# Processing: DUOPA
# Processing: DURACLON
# Processing: DUREZOL
# Processing: DURLAZA
# Processing: DUTASTERIDE
# Processing: DYANAVEL
# Processing: DYAZIDE
# Processing: DYLOJECT
# Processing: DYRENIUM
# Processing: DYURAL
# Processing: ECONAZOLE
# Processing: EDARBI
# Processing: EDARBYCLOR
# Processing: EDECRIN
# Processing: EDEX
# Processing: EDLUAR
# Processing: EDURANT
# Processing: EFFIENT
# Processing: EFUDEX
# Processing: EGRIFTA
# Processing: ELDEPRYL
# Processing: ELELYSO
# Processing: ELESTAT
# Processing: ELESTRIN
# Processing: ELIDEL
# Processing: ELIGARD
# Processing: ELIMITE
# Processing: ELIQUIS
# Processing: ELLA
# Processing: ELLENCE
# Processing: ELLIOTTS
# Processing: ELMIRON
# Processing: ELOCON0
# Processing: ELOCON1
# Processing: ELOCTATE
# Processing: ELOXATIN
# Processing: EMADINE
# Processing: EMBEDA
# Processing: EMCYT
# Processing: EMEND0
# Processing: EMEND1
# Processing: EMSAM
# Processing: EMTRIVA0
# Processing: EMTRIVA1
# Processing: ENALAPRIL
# Processing: ENDODAN
# Processing: ENDOMETRIN
# Processing: ENGERIXB
# Processing: ENLON
# Processing: ENOXAPARIN
# Processing: ENSTILAR
# Processing: ENTACAPONE
# Processing: ENTEREG
# Processing: ENTOCORT
# Processing: ENTRESTO
# Processing: ENTYVIO
# Processing: ENVARSUS
# Processing: EOVIST
# Processing: EPANED
# Processing: EPCLUSA
# Processing: EPIDUO
# Processing: EPINEPHRINE0
# Processing: EPINEPHRINE1
# Processing: EPIVIR0
# Processing: EPIVIR1
# Processing: EPIVIR2
# Processing: EPLERENONE
# Processing: EPTIFIBATIDE
# Processing: EPZICOM
# Processing: EQUETRO
# Processing: EQUUS
# Processing: ERAXIS
# Processing: ERIVEDGE
# Processing: ERTACZO
# Processing: ERYGEL
# Processing: ERYPED
# Processing: ERYTHROCIN
# Processing: ERYTHROMYCIN
# Processing: ERYTHROMYCINBENZOYL
# Processing: ESBRIET
# Processing: ESBRIET0
# Processing: ESBRIET1
# Processing: ESMOLOL
# Processing: ESTRADIOL
# Processing: ESTRING
# Processing: ESTROGEL
# Processing: ETHAMBUTOL
# Processing: ETHAMOLIN
# Processing: ETOPOPHOS
# Processing: EUCRISA
# Processing: EURAX
# Processing: EVAMIST
# Processing: EVARREST
# Processing: EVICEL
# Processing: EVISTA
# Processing: EVITHROM
# Processing: EVOCLIN
# Processing: EVOTAZ
# Processing: EVOXAC
# Processing: EVZIO0
# Processing: EVZIO1
# Processing: EXALGO
# Processing: EXCEDRIN
# Processing: EXELDERM0
# Processing: EXELDERM1
# Processing: EXELON
# Processing: EXEMESTANE
# Processing: EXFORGE0
# Processing: EXFORGE1
# Processing: EXJADE
# Processing: EXONDYS
# Processing: EXPAREL
# Processing: EXTINA
# Processing: EXTRANEAL
# Processing: EZHD
# Processing: FABIOR
# Processing: FACTIVE
# Processing: FAMVIR
# Processing: FANAPT
# Processing: FARESTON
# Processing: FARXIGA
# Processing: FARYDAK
# Processing: FASLODEX
# Processing: FEIBA
# Processing: FELBATOL
# Processing: FELODIPINEEXTENDEDRELEASE
# Processing: FEMARA
# Processing: FEMCON
# Processing: FEMHRT
# Processing: FEMRING
# Processing: FENOFIBRATE0
# Processing: FENOFIBRATE1
# Processing: FENOFIBRIC
# Processing: FENORTHO
# Processing: FENTANYL
# Processing: FENTANYL0
# Processing: FENTANYL1
# Processing: FENTANYL2
# Processing: FENTORA
# Processing: FERAHEME
# Processing: FERRIPROX0
# Processing: FERRIPROX1
# Processing: FERRLECIT
# Processing: FETZIMA
# Processing: FEXOFENADINE
# Processing: FINACEA
# Processing: FIRAZYR
# Processing: FIRMAGON
# Processing: FLAGYL0
# Processing: FLAGYL1
# Processing: FLAREX
# Processing: FLEBOGAMMA
# Processing: FLECAINIDE
# Processing: FLECTOR
# Processing: FLOLAN
# Processing: FLOMAX
# Processing: FLOVENT0
# Processing: FLOVENT1
# Processing: FLUAD
# Processing: FLUARIX
# Processing: FLUBLOK
# Processing: FLUCELVAX
# Processing: FLUCONAZOLE
# Processing: FLUDARABINE
# Processing: FLUDEOXYGLUCOSE
# Processing: FLULAVAL
# Processing: FLUMIST
# Processing: FLUOCINONIDE0
# Processing: FLUOCINONIDE1
# Processing: FLUORESCITE
# Processing: FLUOROMETHOLONE
# Processing: FLUOROPLEX
# Processing: FLUOXETINE
# Processing: FLURANDRENOLIDE0
# Processing: FLURANDRENOLIDE1
# Processing: FLURBIPROFEN
# Processing: FLUTICASONE
# Processing: FLUVIRIN
# Processing: FML
# Processing: FOCALINXR
# Processing: FOLLISTIM
# Processing: FOLOTYN
# Processing: FONDAPARINUX
# Processing: FOOD
# Processing: FORADIL
# Processing: FORANE
# Processing: FORFIVO
# Processing: FORTAZ
# Processing: FORTEO
# Processing: FORTESTA
# Processing: FOSAMAX
# Processing: FOSCAVIR
# Processing: FOSRENOL0
# Processing: FOSRENOL1
# Processing: FRAGMIN
# Processing: FROVA
# Processing: FULYZAQ
# Processing: FURADANTIN
# Processing: FUROSEMIDE
# Processing: FUSILEV
# Processing: FUZEON
# Processing: FYCOMPA
# Processing: GABAPENTIN
# Processing: GABITRIL
# Processing: GADAVIST
# Processing: GADOPENTETATE0
# Processing: GADOPENTETATE1
# Processing: GALANTAMINE
# Processing: GALZIN
# Processing: GAMASTAN
# Processing: GAMMAGARD0
# Processing: GAMMAGARD1
# Processing: GAMMAKED
# Processing: GAMMAPLEX
# Processing: GANIRELIX
# Processing: GARDASIL0
# Processing: GARDASIL1
# Processing: GASTROCROM
# Processing: GASTROGRAFIN
# Processing: GATTEX
# Processing: GAZYVA
# Processing: GELNIQUE
# Processing: GEMCITABINE
# Processing: GEMZAR
# Processing: GENERESS
# Processing: GENOTROPIN
# Processing: GENVOYA
# Processing: GEODON
# Processing: GIAZO
# Processing: GILENYA
# Processing: GILOTRIF
# Processing: GINTUIT
# Processing: GLASSIA
# Processing: GLEEVEC
# Processing: GLEOSTINE
# Processing: GLIADEL
# Processing: GLIPIZIDE
# Processing: GLUCAGEN
# Processing: GLUCAGON0
# Processing: GLUCAGON1
# Processing: GLUCOPHAGE
# Processing: GLUCOTROL
# Processing: GLUCOVANCE
# Processing: GLUMETZA
# Processing: GLYNASE
# Processing: GLYSET
# Processing: GLYXAMBI
# Processing: GONALF
# Processing: GONALF0
# Processing: GONALF1
# Processing: GONITRO
# Processing: GRALISE
# Processing: GRASTEK
# Processing: GRISPEG
# Processing: HAEMONETICS0
# Processing: HALAVEN
# Processing: HALDOL
# Processing: HALOG
# Processing: HALOPERIDOL
# Processing: HARVONI
# Processing: HAVRIX
# Processing: HECTOROL
# Processing: HEMABATE
# Processing: HEMACORD
# Processing: HEMANGEOL
# Processing: HEMOFIL
# Processing: HEPAGAM
# Processing: HEPARIN0
# Processing: HEPARIN1
# Processing: HEPARIN2
# Processing: HEPARIN3
# Processing: HEPARIN4
# Processing: HEPARIN5
# Processing: HEPSERA
# Processing: HETLIOZ
# Processing: HEXALEN
# Processing: HEXTEND
# Processing: HIBERIX
# Processing: HIPREX
# Processing: HISTAMINE
# Processing: HIZENTRA
# Processing: HONEY
# Processing: HORIZANT
# Processing: HOUSE
# Processing: HUMALOG0
# Processing: HUMALOG1
# Processing: HUMALOG3
# Processing: HUMALOG4
# Processing: HUMAN
# Processing: HUMATEP
# Processing: HUMATROPE
# Processing: HUMULIN0
# Processing: HUMULIN1
# Processing: HYCAMTIN0
# Processing: HYCAMTIN1
# Processing: HYCOFENIX
# Processing: HYDREA
# Processing: HYDROCHLOROTHIAZIDE
# Processing: HYDROCODONE
# Processing: HYDROCORTISONE0
# Processing: HYDROCORTISONE1
# Processing: HYDROCORTISONE2
# Processing: HYDROCORTISONE3
# Processing: HYDROCORTISONE4
# Processing: HYDROCORTISONE5
# Processing: HYDROMORPHONE0
# Processing: HYDROMORPHONE1
# Processing: HYDROXYCHLOROQUINE
# Processing: HYDROXYETHYL
# Processing: HYLENEX
# Processing: HYPERHEP
# Processing: HYPERRAB
# Processing: HYPERRHO
# Processing: HYPERTET
# Processing: HYQVIA
# Processing: HYSINGLA
# Processing: HYZAAR
# Processing: IBRANCE
# Processing: IBUPROFEN
# Processing: ICGREEN
# Processing: ICLUSIG
# Processing: IDAMYCIN
# Processing: IDELVION
# Processing: IDKIT
# Processing: ILEVRO
# Processing: ILUVIEN
# Processing: IMBRUVICA
# Processing: IMIPRAMINE
# Processing: IMITREX0
# Processing: IMITREX1
# Processing: IMLYGIC
# Processing: IMOGAM
# Processing: IMOVAX
# Processing: IMPAVIDO
# Processing: IMPLANON
# Processing: IMURAN
# Processing: INCRELEX
# Processing: INCRUSE
# Processing: INDICLOR
# Processing: INDIUM
# Processing: INDOCIN
# Processing: INDOMETHACIN
# Processing: INFANRIX
# Processing: INFASURF
# Processing: INFED
# Processing: INFUMORPH
# Processing: INJECTAFER
# Processing: INLYTA
# Processing: INOMAX
# Processing: INTEGRILIN
# Processing: INTELENCE
# Processing: INTERMEZZO
# Processing: INTERSOL
# Processing: INTRALIPID0
# Processing: INTRALIPID1
# Processing: INTRALIPID2
# Processing: INTRALIPID3
# Processing: INTUNIV
# Processing: INVANZ
# Processing: INVEGA0
# Processing: INVEGA1
# Processing: INVEGA2
# Processing: INVIRASE0
# Processing: INVIRASE1
# Processing: INVOKAMET0
# Processing: INVOKAMET1
# Processing: INVOKANA
# Processing: IONSYS
# Processing: IOPIDINE
# Processing: IPOL
# Processing: IPRATROPIUM
# Processing: IPRIVASK
# Processing: IQUIX
# Processing: IRESSA
# Processing: ISENTRESS0
# Processing: ISENTRESS1
# Processing: ISOLYTE
# Processing: ISONIAZID
# Processing: ISOPLATE
# Processing: ISOPTO
# Processing: ISORDIL
# Processing: ISOSORBIDE
# Processing: ISOVUE
# Processing: ISOVUEM
# Processing: ISTALOL
# Processing: ISTODAX
# Processing: ISUPREL
# Processing: IXEMPRA
# Processing: IXINITY
# Processing: JADENU
# Processing: JAKAFI
# Processing: JANUMET0
# Processing: JANUMET1
# Processing: JANUVIA
# Processing: JARDIANCE
# Processing: JEANATOPE
# Processing: JENTADUETO0
# Processing: JENTADUETO1
# Processing: JETREA
# Processing: JEVTANA
# Processing: JOLESSA
# Processing: JUBLIA
# Processing: JUXTAPID
# Processing: KABIVEN
# Processing: KADCYLA
# Processing: KADIAN
# Processing: KALETRA0
# Processing: KALETRA1
# Processing: KALYDECO
# Processing: KARBINAL
# Processing: KAYEXALATE
# Processing: KCENTRA
# Processing: KEDBUMIN
# Processing: KEFLEX
# Processing: KENALOG
# Processing: KENGREAL
# Processing: KEPPRA
# Processing: KEPPRA0
# Processing: KEPPRA1
# Processing: KERYDIN
# Processing: KETAMINE
# Processing: KETOCONAZOLE
# Processing: KEYTRUDA
# Processing: KINEVAC
# Processing: KINRIX
# Processing: KIT
# Processing: KIT0
# Processing: KIT1
# Processing: KLARON
# Processing: KLONOPIN
# Processing: KOATE
# Processing: KOGENATE
# Processing: KOMBIGLYZE
# Processing: KORLYM
# Processing: KOVALTRY
# Processing: KOVANAZE
# Processing: KRYSTEXXA
# Processing: KTAB
# Processing: KUVAN
# Processing: KYBELLA
# Processing: KYLEENA
# Processing: KYNAMRO
# Processing: KYPROLIS
# Processing: LABETALOL
# Processing: LACHYDRIN
# Processing: LACRISERT
# Processing: LACTATED0
# Processing: LACTATED1
# Processing: LACTATED2
# Processing: LACTATED3
# Processing: LAMICTAL0
# Processing: LAMICTAL1
# Processing: LAMICTAL2
# Processing: LAMISIL1
# Processing: LAMISIL2
# Processing: LANOXIN0
# Processing: LANOXIN1
# Processing: LANSOPRAZOLE
# Processing: LANTUS
# Processing: LASIX
# Processing: LASTACAFT
# Processing: LATISSE
# Processing: LATUDA
# Processing: LAVIV
# Processing: LAZANDA
# Processing: LEENA
# Processing: LEFLUNOMIDE
# Processing: LENVIMA
# Processing: LESCOL
# Processing: LETAIRIS
# Processing: LEUKERAN
# Processing: LEUKOTRAP
# Processing: LEVAQUIN
# Processing: LEVEMIR
# Processing: LEVETIRACETAM
# Processing: LEVITRA
# Processing: LEVOBUNOLOL
# Processing: LEVOCARNITINE0
# Processing: LEVOCARNITINE1
# Processing: LEVOPHED
# Processing: LEVOTHROID
# Processing: LEVOTHYROXINE
# Processing: LEVOTHYROXINE0
# Processing: LEVOTHYROXINE1
# Processing: LEVOXYL
# Processing: LEVULAN
# Processing: LEXAPRO
# Processing: LEXISCAN
# Processing: LEXIVA0
# Processing: LEXIVA1
# Processing: LIALDA
# Processing: LIDOCAINE
# Processing: LIDODERM
# Processing: LIDOLOG
# Processing: LINCOCIN
# Processing: LINEZOLID
# Processing: LINZESS
# Processing: LIORESAL
# Processing: LIPIODOL
# Processing: LIPITOR
# Processing: LIPTRUZET
# Processing: LITHIUM1
# Processing: LITHOSTAT
# Processing: LIVALO
# Processing: LO0
# Processing: LO1
# Processing: LOCOID
# Processing: LONSURF
# Processing: LOPID
# Processing: LOPRESSOR0
# Processing: LOPRESSOR1
# Processing: LOPROX0
# Processing: LOPROX1
# Processing: LORAZEPAM
# Processing: LOTEMAX
# Processing: LOTEMAX0
# Processing: LOTEMAX1
# Processing: LOTENSIN0
# Processing: LOTENSIN1
# Processing: LOTRISONE
# Processing: LOTRONEX
# Processing: LOVAZA
# Processing: LUMASON
# Processing: LUMIGAN
# Processing: LUNESTA
# Processing: LUPANETA
# Processing: LUPRON0
# Processing: LUPRON1
# Processing: LUPRON2
# Processing: LUPRON3
# Processing: LUVOX
# Processing: LUXIQ
# Processing: LUZU
# Processing: LYMPHAZURIN
# Processing: LYNPARZA
# Processing: LYRICA0
# Processing: LYRICA1
# Processing: LYSODREN
# Processing: MACI
# Processing: MACUGEN
# Processing: MAGNESIUM0
# Processing: MAGNESIUM1
# Processing: MAGNESIUM2
# Processing: MAKENA
# Processing: MALARONE
# Processing: MARCAINE
# Processing: MARPLAN
# Processing: MARQIBO
# Processing: MATULANE
# Processing: MAVIK
# Processing: MAXALTMLT
# Processing: MAXIDEX
# Processing: MAXIPIME
# Processing: MAXITROL
# Processing: MD76R
# Processing: MEDICAL
# Processing: MEDROL
# Processing: MEDROXYPROGESTERONE
# Processing: MEFENAMIC
# Processing: MEGACE
# Processing: MEGATOPE
# Processing: MEKINIST
# Processing: MELOXICAM
# Processing: MEMBRANEBLUE
# Processing: MENACTRA
# Processing: MENHIBRIX
# Processing: MENOMUNE
# Processing: MENOPUR
# Processing: MENTAX
# Processing: MENVEO
# Processing: MEPHYTON
# Processing: MERREM
# Processing: MESALAMINE
# Processing: MESNEX0
# Processing: MESNEX1
# Processing: MESTINON
# Processing: METADATE
# Processing: METASTRON
# Processing: METFORMIN
# Processing: METHADONE
# Processing: METHADOSE
# Processing: METHERGINE
# Processing: METHOTREXATE
# Processing: METHOXSALEN
# Processing: METHYLPHENIDATE
# Processing: METHYLPHENIDATE0
# Processing: METHYLPHENIDATE1
# Processing: METHYLPHENIDATE2
# Processing: METOLAZONE
# Processing: METOPIRONE
# Processing: METOPROLOL
# Processing: METOZOLV
# Processing: METROGEL
# Processing: METROLOTION
# Processing: METRONIDAZOLE0
# Processing: METRONIDAZOLE1
# Processing: METRONIDAZOLE2
# Processing: MEVACOR
# Processing: MIACALCIN
# Processing: MICARDIS
# Processing: MICROGESTIN
# Processing: MICRONOR
# Processing: MIGLUSTAT
# Processing: MINIPRESS
# Processing: MINIVELLE
# Processing: MINOCIN0
# Processing: MINOCIN1
# Processing: MIOCHOL
# Processing: MIOSTAT
# Processing: MIRAPEX
# Processing: MIRENA
# Processing: MIRVASO
# Processing: MITIGARE
# Processing: MITOSOL
# Processing: MIVACRON
# Processing: MLK
# Processing: MMR
# Processing: MOBIC
# Processing: MODAFINIL
# Processing: MOMETASONE
# Processing: MONOCLATEP
# Processing: MONONINE
# Processing: MONTELUKAST
# Processing: MONUROL
# Processing: MORPHABOND
# Processing: MORPHINE0
# Processing: MORPHINE1
# Processing: MORPHINE2
# Processing: MORPHINE3
# Processing: MORPHINE4
# Processing: MORPHINE5
# Processing: MOVANTIK
# Processing: MOVIPREP
# Processing: MOXATAG
# Processing: MOXEZA
# Processing: MOXIFLOXACIN0
# Processing: MOXIFLOXACIN1
# Processing: MOZOBIL
# Processing: MS
# Processing: MUCOR
# Processing: MULTAQ
# Processing: MULTI
# Processing: MULTIHANCE0
# Processing: MULTIHANCE1
# Processing: MUSE
# Processing: MUSTARGEN
# Processing: MVI0
# Processing: MVI1
# Processing: MYALEPT
# Processing: MYCAMINE
# Processing: MYCOBUTIN
# Processing: MYFORTIC
# Processing: MYLERAN
# Processing: MYOVIEW
# Processing: MYRBETRIQ
# Processing: MYSOLINE
# Processing: NADOLOL
# Processing: NAFCILLIN
# Processing: NAFTIN0
# Processing: NAFTIN1
# Processing: NAFTIN2
# Processing: NAMENDA0
# Processing: NAMENDA1
# Processing: NAMENDA2
# Processing: NAMZARIC
# Processing: NAPRELAN
# Processing: NAPROSYN0
# Processing: NAPROSYN1
# Processing: NARCAN
# Processing: NARDIL
# Processing: NAROPIN
# Processing: NASCOBAL
# Processing: NATACYN
# Processing: NATAZIA
# Processing: NATRECOR
# Processing: NATROBA
# Processing: NAVELBINE
# Processing: NEBUPENT
# Processing: NECON
# Processing: NEOMYCIN
# Processing: NEORAL0
# Processing: NEORAL1
# Processing: NESACAINE
# Processing: NESINA
# Processing: NETSPOT
# Processing: NEUPRO
# Processing: NEURACEQ
# Processing: NEURONTIN
# Processing: NEVANAC
# Processing: NEXAVAR
# Processing: NEXIUM0
# Processing: NEXIUM1
# Processing: NEXIUM2
# Processing: NEXTERONE
# Processing: NIASPAN
# Processing: NICOTROL0
# Processing: NICOTROL1
# Processing: NIFEDIPINE
# Processing: NIFEDIPINE0
# Processing: NIFEDIPINE1
# Processing: NILANDRON
# Processing: NIMBEX
# Processing: NINLARO
# Processing: NIPENT
# Processing: NIRAVAM
# Processing: NISOLDIPINE
# Processing: NITHIODOTE
# Processing: NITRODUR
# Processing: NITROFURANTION
# Processing: NITROFURANTOIN
# Processing: NITROGLYCERIN
# Processing: NITROLINGUAL
# Processing: NITROMIST
# Processing: NORA
# Processing: NORETHINDRONE
# Processing: NORITATE
# Processing: NORPACE0
# Processing: NORPACE1
# Processing: NORPRAMIN
# Processing: NORTHERA
# Processing: NORVASC
# Processing: NORVIR0
# Processing: NORVIR1
# Processing: NOVAREL
# Processing: NOVOEIGHT
# Processing: NOVOLIN0
# Processing: NOVOLIN2
# Processing: NOVOLOG0
# Processing: NOVOLOG1
# Processing: NOVOSEVEN
# Processing: NOXAFIL
# Processing: NPLATE
# Processing: NUCYNTA
# Processing: NUCYNTA0
# Processing: NUCYNTA1
# Processing: NUEDEXTA
# Processing: NUPLAZID
# Processing: NUTRESTORE
# Processing: NUTRILIPID
# Processing: NUTROPIN
# Processing: NUVARING
# Processing: NUVESSA
# Processing: NUVIGIL
# Processing: NUWIQ
# Processing: NYMALIZE
# Processing: OBIZUR
# Processing: OBREDON
# Processing: OCALIVA
# Processing: OCELLA
# Processing: OCTAGAM
# Processing: OCTREOSCAN
# Processing: OCUFLOX
# Processing: ODEFSEY
# Processing: ODOMZO
# Processing: OFEV
# Processing: OFIRMEV
# Processing: OLUXE
# Processing: OLYSIO
# Processing: OMECLAMOXPAK
# Processing: OMEPRAZOLE
# Processing: OMEPRAZOLESODIUM
# Processing: OMIDRIA
# Processing: OMNARIS
# Processing: OMNIPAQUE
# Processing: OMNISCAN0
# Processing: OMNISCAN1
# Processing: OMTRYG
# Processing: ONFI
# Processing: ONGLYZA
# Processing: ONIVYDE
# Processing: ONMEL
# Processing: ONZETRA
# Processing: OPANA
# Processing: OPANA0
# Processing: OPANA1
# Processing: OPDIVO
# Processing: OPSUMIT
# Processing: OPTIMARK0
# Processing: OPTIMARK1
# Processing: OPTIMARK2
# Processing: OPTIRAY0
# Processing: OPTIRAY1
# Processing: OPTISON
# Processing: ORALAIR
# Processing: ORAP
# Processing: ORAPRED
# Processing: ORAQIX
# Processing: ORAVERSE
# Processing: ORAVIG
# Processing: ORBACTIV
# Processing: ORENITRAM
# Processing: ORFADIN
# Processing: ORKAMBI
# Processing: ORTHO
# Processing: ORTHO0
# Processing: ORTHO1
# Processing: ORTHONOVUM0
# Processing: ORTHONOVUM1
# Processing: OSENI
# Processing: OSMOPREP
# Processing: OSPHENA
# Processing: OTEZLA
# Processing: OTIPRIO
# Processing: OTOVEL
# Processing: OTREXUP
# Processing: OVIDE
# Processing: OVIDREL
# Processing: OXACILLIN
# Processing: OXALIPLATIN
# Processing: OXCARBAZEPINE
# Processing: OXICONAZOLE
# Processing: OXISTAT
# Processing: OXTELLAR
# Processing: OXYCODONE
# Processing: OXYCODONE0
# Processing: OXYCODONE1
# Processing: OXYCODONE2
# Processing: OXYTOCIN0
# Processing: OXYTOCIN1
# Processing: OXYTROL
# Processing: OZURDEX
# Processing: PAMELOR
# Processing: PANCREAZE
# Processing: PANDEL
# Processing: PANHEMATIN
# Processing: PANRETIN
# Processing: PANTOPRAZOLE
# Processing: PARAFON
# Processing: PARAGARD
# Processing: PAREMYD
# Processing: PARNATE
# Processing: PATADAY
# Processing: PATANASE
# Processing: PATANOL
# Processing: PAXIL0
# Processing: PAXIL1
# Processing: PAXILCR
# Processing: PAZEO
# Processing: PCE
# Processing: PEDIARIX
# Processing: PEDIATRIC0
# Processing: PEDIATRIC1
# Processing: PEDVAXHIB
# Processing: PEG33500
# Processing: PEG33501
# Processing: PEGANONE
# Processing: PENICILLIN
# Processing: PENLAC
# Processing: PENNSAID
# Processing: PENTACEL
# Processing: PENTAM
# Processing: PENTETATE0
# Processing: PENTETATE1
# Processing: PEPCID0
# Processing: PERFOROMIST
# Processing: PERIDEX
# Processing: PERIOCHIP
# Processing: PERJETA
# Processing: PERTZYE
# Processing: PEXEVA
# Processing: PHENDIMETRAZINE
# Processing: PHENOXYBENZAMINE
# Processing: PHENYLEPHRINE0
# Processing: PHENYLEPHRINE1
# Processing: PHENYLEPHRINE2
# Processing: PHOSLYRA
# Processing: PHOSPHOLINE
# Processing: PHOTREXA
# Processing: PHOXILLUM
# Processing: PICATO
# Processing: PILOCARPINE
# Processing: PIOGLITAZONE
# Processing: PIROXICAM
# Processing: PITOCIN
# Processing: PLAN0
# Processing: PLASBUMIN
# Processing: PLASMANATE
# Processing: PLAVIX
# Processing: PLEGISOL
# Processing: PLEGRIDY
# Processing: PLETAL
# Processing: PLIAGLIS
# Processing: PNEUMOVAX
# Processing: POLLENS
# Processing: POLYMYXIN
# Processing: POMALYST
# Processing: POSITIVE
# Processing: POTASSIUM0
# Processing: POTASSIUM1
# Processing: POTASSIUM2
# Processing: POTASSIUM3
# Processing: POTASSIUM4
# Processing: POTASSIUM5
# Processing: POTASSIUM6
# Processing: POTASSIUM7
# Processing: POTIGA
# Processing: PRADAXA
# Processing: PRALIDOXIME
# Processing: PRANDIMET
# Processing: PRANDIN
# Processing: PRAVACHOL
# Processing: PRECOSE
# Processing: PRED0
# Processing: PRED1
# Processing: PREDG0
# Processing: PREDG1
# Processing: PREDNICARBATE
# Processing: PREDNISOLONE
# Processing: PREGNYL
# Processing: PREMARIN0
# Processing: PREMARIN1
# Processing: PREMARIN2
# Processing: PREMPRO
# Processing: PREPEN
# Processing: PREPIDIL
# Processing: PREPOPIK
# Processing: PRESTALIA
# Processing: PREVACID0
# Processing: PREVACID2
# Processing: PREVNAR
# Processing: PREZCOBIX
# Processing: PREZISTA0
# Processing: PREZISTA1
# Processing: PRIALT
# Processing: PRIFTIN
# Processing: PRILOSEC
# Processing: PRIMAQUINE
# Processing: PRIMAXIN
# Processing: PRIMSOL
# Processing: PRISMASOL
# Processing: PRISTIQ
# Processing: PRIVIGEN
# Processing: PROAIR
# Processing: PROBUPHINE
# Processing: PROCYSBI
# Processing: PROFILNINE
# Processing: PROGESTERONE
# Processing: PROGLYCEM
# Processing: PROGRAF0
# Processing: PROGRAF1
# Processing: PROHANCE0
# Processing: PROHANCE1
# Processing: PROLASTINC
# Processing: PROLENSA
# Processing: PROMACTA
# Processing: PROMETRIUM
# Processing: PROPECIA
# Processing: PROPRANOLOL
# Processing: PROPYLTHIOURACIL
# Processing: PROQUAD
# Processing: PROSCAR
# Processing: PROSOL
# Processing: PROSTIN
# Processing: PROTONIX0
# Processing: PROTONIX1
# Processing: PROTOPAM
# Processing: PROTOPIC
# Processing: PROVAYBLUE
# Processing: PROVENGE
# Processing: PROVENTIL
# Processing: PROVOCHOLINE
# Processing: PROZAC0
# Processing: PROZAC1
# Processing: PULMICORT0
# Processing: PULMICORT1
# Processing: PURWASH
# Processing: PYLERA
# Processing: PYRIDOSTIGMINE
# Processing: PYTEST
# Processing: QBRELIS
# Processing: QNASL
# Processing: QSYMIA
# Processing: QUADRACEL
# Processing: QUADRAMET
# Processing: QUARTETTE
# Processing: QUAZEPAM
# Processing: QUDEXY
# Processing: QUELICIN
# Processing: QUILLICHEW
# Processing: QUILLIVANT
# Processing: QUINAPRIL
# Processing: QUINIDINE
# Processing: QUININE
# Processing: QUIXIN
# Processing: QUTENZA
# Processing: QVAR
# Processing: RABAVERT
# Processing: RADIOGARDASE
# Processing: RAGWITEK
# Processing: RANEXA
# Processing: RAPAFLO
# Processing: RAPAMUNE0
# Processing: RAPAMUNE1
# Processing: RAPIVAB
# Processing: RAPLIXA
# Processing: RAVICTI
# Processing: RAXIBACUMAB
# Processing: RAYALDEE
# Processing: RAYOS
# Processing: REBETOL
# Processing: RECLAST
# Processing: RECOMBINATE
# Processing: RECOMBIVAX
# Processing: RECOTHROM
# Processing: RECTIV
# Processing: REGLAN
# Processing: RELENZA
# Processing: RELISTOR
# Processing: RELPAX
# Processing: REMERON
# Processing: REMERONSOLTAB
# Processing: REMODULIN
# Processing: RENACIDIN
# Processing: RENAGEL
# Processing: RENOVA
# Processing: RENVELA0
# Processing: RENVELA1
# Processing: REQUIP0
# Processing: REQUIP1
# Processing: RESCRIPTOR
# Processing: RESCULA
# Processing: RESERPINE
# Processing: RESTASIS
# Processing: RESTORIL
# Processing: RETINA0
# Processing: RETINA1
# Processing: RETISERT
# Processing: RETROVIR
# Processing: REVATIO
# Processing: REVLIMID
# Processing: REXULTI
# Processing: REYATAZ0
# Processing: REYATAZ1
# Processing: REZIRA
# Processing: RGENE
# Processing: RHOFADE
# Processing: RHOGAM
# Processing: RHOPHYLAC
# Processing: RIASTAP
# Processing: RIDAURA
# Processing: RIFADIN
# Processing: RIFATER
# Processing: RILUTEK
# Processing: RIMSO50
# Processing: RIOMET
# Processing: RISEDRONATE
# Processing: RISPERDAL0
# Processing: RISPERDAL1
# Processing: RISPERIDONE
# Processing: RIVASTIGMINE
# Processing: RIXUBIS
# Processing: ROBAXIN
# Processing: ROBINUL0
# Processing: ROBINUL1
# Processing: ROCALTROL
# Processing: ROTARIX
# Processing: ROTATEQ
# Processing: ROWASA
# Processing: ROXICODONE
# Processing: ROZEREM
# Processing: RUBRACA
# Processing: RUCONEST
# Processing: RYANODEX
# Processing: RYTARY
# Processing: RYTHMOL0
# Processing: RYTHMOL1
# Processing: RYZOLT
# Processing: SABRIL
# Processing: SABRIL0
# Processing: SABRIL1
# Processing: SAIZEN
# Processing: SAMSCA
# Processing: SANCUSO
# Processing: SANDIMMUNE
# Processing: SANDOSTATIN0
# Processing: SANDOSTATIN1
# Processing: SAPHRIS
# Processing: SARAFEM
# Processing: SAVAYSA
# Processing: SAVELLA
# Processing: SAXENDA
# Processing: SCLEROSOL
# Processing: SECTRAL
# Processing: SEEBRI
# Processing: SELZENTRY0
# Processing: SELZENTRY1
# Processing: SEMPREX
# Processing: SENSIPAR
# Processing: SEREVENT
# Processing: SERNIVO
# Processing: SEROQUEL0
# Processing: SEROQUEL1
# Processing: SERTRALINE0
# Processing: SERTRALINE1
# Processing: SHORT0
# Processing: SHORT1
# Processing: SIGNIFOR
# Processing: SIGNIFOR0
# Processing: SIGNIFOR1
# Processing: SILDENAFIL
# Processing: SILENOR
# Processing: SILVADENE
# Processing: SIMBRINZA
# Processing: SINEMET0
# Processing: SINEMET1
# Processing: SINGULAIR
# Processing: SINOGRAFIN
# Processing: SIRTURO
# Processing: SITAVIG
# Processing: SIVEXTRO
# Processing: SKELAXIN
# Processing: SKLICE
# Processing: SKYLA
# Processing: SMOFLIPID
# Processing: SODIUM0
# Processing: SODIUM1
# Processing: SODIUM10
# Processing: SODIUM11
# Processing: SODIUM12
# Processing: SODIUM13
# Processing: SODIUM14
# Processing: SODIUM15
# Processing: SODIUM16
# Processing: SODIUM17
# Processing: SODIUM18
# Processing: SODIUM19
# Processing: SODIUM2
# Processing: SODIUM3
# Processing: SODIUM4
# Processing: SODIUM5
# Processing: SODIUM6
# Processing: SODIUM7
# Processing: SODIUM8
# Processing: SODIUM9
# Processing: SOLIQUA
# Processing: SOLODYN
# Processing: SOLUCORTEF
# Processing: SOLUMEDROL
# Processing: SOLVENTDETERGENT
# Processing: SOMA
# Processing: SOMATULINE
# Processing: SOMAVERT
# Processing: SOOLANTRA
# Processing: SORIATANE
# Processing: SORILUX
# Processing: SOTALOL
# Processing: SOTYLIZE
# Processing: SOVALDI
# Processing: SPHERUSOL
# Processing: SPINOSAD
# Processing: SPINRAZA
# Processing: SPIRIVA0
# Processing: SPIRIVA1
# Processing: SPIRONOLACTONE
# Processing: SPORANOX0
# Processing: SPORANOX1
# Processing: SPRITAM
# Processing: SPRIX
# Processing: SPRYCEL
# Processing: STANDARDIZED0
# Processing: STANDARDIZED1
# Processing: STANDARDIZED10
# Processing: STANDARDIZED11
# Processing: STANDARDIZED12
# Processing: STANDARDIZED13
# Processing: STANDARDIZED14
# Processing: STANDARDIZED15
# Processing: STANDARDIZED2
# Processing: STANDARDIZED3
# Processing: STANDARDIZED4
# Processing: STANDARDIZED5
# Processing: STANDARDIZED6
# Processing: STANDARDIZED7
# Processing: STANDARDIZED8
# Processing: STANDARDIZED9
# Processing: STARLIX
# Processing: STAXYN
# Processing: STELARA
# Processing: STENDRA
# Processing: STERILE
# Processing: STERILE0
# Processing: STERILE1
# Processing: STERILE2
# Processing: STERILE3
# Processing: STERILE4
# Processing: STERILE5
# Processing: STIMATE
# Processing: STIOLTO
# Processing: STIVARGA
# Processing: STRATTERA
# Processing: STRIANT
# Processing: STRIBILD
# Processing: STRIVERDI
# Processing: STROMECTOL
# Processing: SUBOXONE0
# Processing: SUBOXONE1
# Processing: SUBSYS
# Processing: SUCRAID
# Processing: SUCRALFATE
# Processing: SUFENTANIL
# Processing: SULFAMYLON0
# Processing: SULFAMYLON1
# Processing: SULFASALAZINE
# Processing: SUMATRIPTAN
# Processing: SUMAVEL
# Processing: SUPPRELIN
# Processing: SUPRANE
# Processing: SUPRAX
# Processing: SUPREP
# Processing: SURFAXIN
# Processing: SURMONTIL
# Processing: SURVANTA
# Processing: SUSTIVA0
# Processing: SUSTIVA1
# Processing: SUSTOL
# Processing: SUTENT
# Processing: SYLVANT
# Processing: SYMBICORT
# Processing: SYMBYAX
# Processing: SYMLINPEN
# Processing: SYNALAR0
# Processing: SYNALAR1
# Processing: SYNALAR2
# Processing: SYNALGOS
# Processing: SYNAREL
# Processing: SYNERA
# Processing: SYNERCID
# Processing: SYNJARDY
# Processing: SYNRIBO
# Processing: SYNTHROID
# Processing: SYPRINE
# Processing: TABLOID
# Processing: TACHOSIL
# Processing: TACLONEX
# Processing: TAFINLAR
# Processing: TAGRISSO
# Processing: TALWIN
# Processing: TAMIFLU0
# Processing: TAMIFLU1
# Processing: TARCEVA
# Processing: TARGRETIN0
# Processing: TARGRETIN1
# Processing: TARKA
# Processing: TASIGNA
# Processing: TASMAR
# Processing: TAXOTERE
# Processing: TAZORAC
# Processing: TECFIDERA
# Processing: TECHNELITE
# Processing: TECHNESCAN
# Processing: TECHNETIUM
# Processing: TECHNIVIE
# Processing: TEFLARO
# Processing: TEGRETOL0
# Processing: TEGRETOL1
# Processing: TEKTURNA0
# Processing: TEKTURNA1
# Processing: TELMISARTAN
# Processing: TEMODAR
# Processing: TEMOVATE0
# Processing: TEMOVATE1
# Processing: TENEX
# Processing: TENIPOSIDE
# Processing: TENIVAC
# Processing: TENORETIC
# Processing: TENORMIN
# Processing: TERAZOL
# Processing: TERCONAZOLE0
# Processing: TERCONAZOLE1
# Processing: TERUFLEX
# Processing: TESSALON
# Processing: TESTIM
# Processing: TETANUS
# Processing: TETRABENAZINE
# Processing: TETRACAINE
# Processing: TETRACYCLINE
# Processing: THALLOUS
# Processing: THALOMID
# Processing: THAM
# Processing: THEOPHYLLINE0
# Processing: THEOPHYLLINE1
# Processing: THERACYS
# Processing: THIOLA
# Processing: THROMBATE
# Processing: THROMBIN
# Processing: THROMBINJMI
# Processing: THYMOGLOBULIN
# Processing: THYROGEN
# Processing: THYROLAR
# Processing: TICALAST
# Processing: TICE
# Processing: TIGAN
# Processing: TIKOSYN
# Processing: TILIA
# Processing: TIMOPTIC0
# Processing: TIMOPTIC1
# Processing: TIMOPTICXE
# Processing: TINDAMAX
# Processing: TIROSINT
# Processing: TISSEEL
# Processing: TIVICAY
# Processing: TIVORBEX
# Processing: TOBI0
# Processing: TOBI1
# Processing: TOBRADEX
# Processing: TOBRAMYCIN
# Processing: TOBREX
# Processing: TOLAK
# Processing: TOLTERODINE
# Processing: TOPAMAX0
# Processing: TOPAMAX1
# Processing: TOPICORT
# Processing: TOPOTECAN0
# Processing: TOPOTECAN1
# Processing: TOPROL
# Processing: TORISEL
# Processing: TOUJEO
# Processing: TOVIAZ
# Processing: TPN
# Processing: TRACLEER
# Processing: TRADJENTA
# Processing: TRAMADOL0
# Processing: TRAMADOL1
# Processing: TRANEXAMIC
# Processing: TRANSDERM
# Processing: TRANXENE
# Processing: TRAVATAN
# Processing: TREANDA
# Processing: TRECATOR
# Processing: TRELSTAR
# Processing: TRESIBA
# Processing: TRETTEN
# Processing: TREXIMET
# Processing: TRIAMCINOLONE
# Processing: TRIAMTERENE
# Processing: TRIAZOLAM
# Processing: TRIBENZOR
# Processing: TRICITRASOL
# Processing: TRICOR
# Processing: TRIDIONE
# Processing: TRIESENCE
# Processing: TRIFERIC0
# Processing: TRIFERIC1
# Processing: TRIFLURIDINE
# Processing: TRIGLIDE
# Processing: TRILEPTAL
# Processing: TRILIPIX
# Processing: TRILUMA
# Processing: TRIMETHOPRIM
# Processing: TRINESSA
# Processing: TRINTELLIX
# Processing: TRIOSTAT
# Processing: TRISENOX
# Processing: TRIUMEQ
# Processing: TRIZIVIR
# Processing: TROKENDI
# Processing: TROPHAMINE
# Processing: TRUE
# Processing: TRULANCE
# Processing: TRUMENBA
# Processing: TRUSOPT
# Processing: TRUVADA
# Processing: TUBERSOL
# Processing: TUDORZA
# Processing: TUSSIONEX
# Processing: TUZISTRA
# Processing: TWINRIX
# Processing: TWYNSTA
# Processing: TYBOST
# Processing: TYGACIL
# Processing: TYKERB
# Processing: TYPHIM
# Processing: TYVASO
# Processing: TYZEKA
# Processing: UCERIS0
# Processing: UCERIS1
# Processing: ULESFIA
# Processing: ULORIC
# Processing: ULTANE
# Processing: ULTIVA
# Processing: ULTRAM
# Processing: ULTRATAG
# Processing: ULTRATECHNEKOW
# Processing: ULTRAVATE0
# Processing: ULTRAVATE1
# Processing: ULTRAVIST0
# Processing: ULTRAVIST1
# Processing: ULTRESA
# Processing: UNASYN
# Processing: UPTRAVI
# Processing: UROXATRAL
# Processing: URSODIOL0
# Processing: URSODIOL1
# Processing: UTIBRON
# Processing: UVADEX
# Processing: VALCHLOR
# Processing: VALCYTE
# Processing: VALIUM
# Processing: VALSARTAN
# Processing: VALSTAR
# Processing: VALTREX
# Processing: VANCOMYCIN
# Processing: VANIQA
# Processing: VANOS
# Processing: VANTAS
# Processing: VAPRISOL
# Processing: VAQTA
# Processing: VARIBAR
# Processing: VARITHENA
# Processing: VARIVAX
# Processing: VARIZIG
# Processing: VARUBI
# Processing: VASCEPA
# Processing: VASOSTRICT
# Processing: VASOTEC
# Processing: VAXCHORA
# Processing: VAZCULEP
# Processing: VELCADE
# Processing: VELETRI
# Processing: VELPHORO
# Processing: VELTASSA
# Processing: VELTIN
# Processing: VEMLIDY
# Processing: VENCLEXTA
# Processing: VENLAFAXINE
# Processing: VENOFER
# Processing: VENTAVIS
# Processing: VENTOLIN
# Processing: VERAPAMIL0
# Processing: VERAPAMIL1
# Processing: VERDESO
# Processing: VEREGEN
# Processing: VERELAN
# Processing: VERMOX
# Processing: VERSACLOZ
# Processing: VESICARE
# Processing: VFEND0
# Processing: VFEND1
# Processing: VIAGRA
# Processing: VIBATIV
# Processing: VIBERZI
# Processing: VIBRAMYCIN
# Processing: VICOPROFEN
# Processing: VICTOZA
# Processing: VIDAZA
# Processing: VIDEX0
# Processing: VIDEX1
# Processing: VIEKIRA
# Processing: VIEKIRA0
# Processing: VIEKIRA1
# Processing: VIGAMOX
# Processing: VIIBRYD
# Processing: VIMOVO
# Processing: VIMPAT
# Processing: VIMPAT0
# Processing: VIMPAT1
# Processing: VIOKACE
# Processing: VIRACEPT
# Processing: VIRAMUNE0
# Processing: VIRAMUNE1
# Processing: VIRAMUNE2
# Processing: VIRAZOLE
# Processing: VIREAD0
# Processing: VIREAD1
# Processing: VISIONBLUE
# Processing: VISIPAQUE
# Processing: VISTARIL0
# Processing: VISTARIL1
# Processing: VISTIDE
# Processing: VISTOGARD
# Processing: VISUDYNE
# Processing: VITRASE
# Processing: VITUZ
# Processing: VIVELLE
# Processing: VIVITROL
# Processing: VIVLODEX
# Processing: VIVOTIF
# Processing: VIZAMYL
# Processing: VOLTAREN
# Processing: VOLUVEN
# Processing: VONVENDI
# Processing: VORICONAZOLE
# Processing: VOTRIENT
# Processing: VPRIV
# Processing: VRAYLAR
# Processing: VUSION
# Processing: VYTORIN
# Processing: VYVANSE
# Processing: WELCHOL
# Processing: WELLBUTRIN
# Processing: WELLBUTRINXL
# Processing: WESTCORT
# Processing: WILATE
# Processing: WINRHO
# Processing: XALATAN
# Processing: XALKORI
# Processing: XARELTO
# Processing: XARTEMIS
# Processing: XELJANZ
# Processing: XELODA
# Processing: XENAZINE
# Processing: XENICAL
# Processing: XERESE
# Processing: XIFAXAN0
# Processing: XIFAXAN1
# Processing: XIGDUO
# Processing: XIIDRA
# Processing: XOFIGO
# Processing: XOLEGEL
# Processing: XOPENEX0
# Processing: XOPENEX1
# Processing: XTAMPZA
# Processing: XTANDI
# Processing: XULTOPHY
# Processing: XURIDEN
# Processing: XYLOCAINE0
# Processing: XYLOCAINE1
# Processing: XYLOCAINE2
# Processing: XYLOCAINEMPF
# Processing: XYNTHA
# Processing: XYREM
# Processing: XYZAL1
# Processing: YAZ
# Processing: YFVAX
# Processing: YONDELIS
# Processing: YOSPRALA
# Processing: YUVAFEM
# Processing: ZAFIRLUKAST
# Processing: ZALEPLON
# Processing: ZALTRAP
# Processing: ZANAFLEX0
# Processing: ZANAFLEX1
# Processing: ZANOSAR
# Processing: ZANTAC0
# Processing: ZANTAC1
# Processing: ZARONTIN
# Processing: ZAZOLE
# Processing: ZECUITY
# Processing: ZELAPAR
# Processing: ZELBORAF
# Processing: ZEMAIRA
# Processing: ZEMPLAR
# Processing: ZEMURON
# Processing: ZENPEP
# Processing: ZEPATIER
# Processing: ZERBAXA
# Processing: ZERIT
# Processing: ZESTORETIC
# Processing: ZESTRIL
# Processing: ZETIA
# Processing: ZETONNA
# Processing: ZIAC
# Processing: ZIAGEN0
# Processing: ZIAGEN1
# Processing: ZIANA
# Processing: ZINACEF
# Processing: ZINC
# Processing: ZINECARD
# Processing: ZIOPTAN
# Processing: ZIPSOR
# Processing: ZIRGAN
# Processing: ZITHROMAX
# Processing: ZMAX
# Processing: ZOCOR
# Processing: ZOFRAN0
# Processing: ZOFRAN1
# Processing: ZOHYDRO
# Processing: ZOLADEX0
# Processing: ZOLADEX1
# Processing: ZOLINZA
# Processing: ZOLMITRIPTAN
# Processing: ZOLPIMIST
# Processing: ZOMACTON
# Processing: ZOMETA
# Processing: ZOMIG
# Processing: ZONEGRAN
# Processing: ZONTIVITY
# Processing: ZORBTIVE
# Processing: ZORTRESS
# Processing: ZORVOLEX
# Processing: ZOSTAVAX
# Processing: ZOSYN
# Processing: ZOVIRAX
# Processing: ZOVIRAX0
# Processing: ZOVIRAX1
# Processing: ZUBSOLV
# Processing: ZUPLENZ
# Processing: ZURAMPIC
# Processing: ZYBAN
# Processing: ZYCLARA
# Processing: ZYDELIG
# Processing: ZYFLO0
# Processing: ZYFLO1
# Processing: ZYKADIA
# Processing: ZYLET
# Processing: ZYLOPRIM
# Processing: ZYMAXID
# Processing: ZYPREXA0
# Processing: ZYPREXA1
# Processing: ZYTIGA
# Processing: ZYVOX0
# Processing: ZYVOX1

# %%
len(test)
# Out:
# 3594380

# %%
test[0]
# Out:
# ['8MOP', u'S2', u'boxed', 6, 11]

# %%
with open("test.csv", "wb") as f:
    writer = csv.writer(f)
    writer.writerows(test)
