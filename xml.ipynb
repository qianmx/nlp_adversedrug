# %% [markdown]
# https://bionlp.nlm.nih.gov/tac2017adversereactions/

# %% [markdown]
# Task 1: Extract AdverseReactions and related mentions (Severity, Factor, DrugClass, Negation, Animal). This is similar to many NLP Named Entity Recognition (NER) evaluations.

# %%
import untangle
import glob
import pandas as pd
from collections import Counter
import re
import string

# %%
path = '/Users/jzhu/git/nlp_adversedrug/data/train_xml/'

# %%
def parse_xml(filename):
    """
    @input a filename string
    @return:
    1. For training data: both a dictionary (key is the section) for X (text strings) and a list of dictionary for y 
        (keys: id (not for task 1), section, type, start, len)
    2. For test data: only a list of X
    """
    X = {}
    Y = []
    
    obj = untangle.parse(filename)
    for text in obj.Label.Text.Section:
        X[text['id']] = text.cdata
        
    if obj.Label.Mentions.Mention:
        for mention in obj.Label.Mentions.Mention:
            entity = {}
            entity['id'] = mention['id']
            entity['section'] = mention['section']
            entity['type'] = mention['type']
            entity['start'] = mention['start']
            entity['len'] = mention['len']
            entity['text'] = mention['str']
            Y.append(entity)
            
    return X, Y

# %% [markdown]
# # test

# %%
filename = path + 'ADCETRIS.xml'
X, Y = parse_xml(filename)

# %%
X.keys()
# Out:
# [u'S3', u'S2', u'S1']

# %%
X['S1']
# Out:
# u'    6 ADVERSE REACTIONS\n\n  The following serious adverse reactions are discussed in greater detail in other sections of the prescribing information:\n\n\n\n *  Peripheral Neuropathy [see  Warnings and Precautions (      5.1      )  ]  \n *  Anaphylaxis and Infusion Reactions [see  Warnings and Precautions (      5.2      )  ]  \n *  Hematologic Toxicities [see  Warnings and Precautions (      5.3      )  ]  \n *  Serious Infections and Opportunistic Infections [see  Warnings and Precautions (      5.4      )  ]  \n *  Tumor Lysis Syndrome [see  Warnings and Precautions (      5.5      )  ]  \n *  Increased Toxicity in the Presence of Severe Renal Impairment [see  Warnings and Precautions (      5.6      )  ]  \n *  Increased Toxicity in the Presence of Moderate or Severe Hepatic Impairment [see  Warnings and Precautions (      5.7      )  ]  \n *  Hepatotoxicity [see  Warnings and Precautions (      5.8      )  ]  \n *  Progressive Multifocal Leukoencephalopathy [see  Warnings and Precautions (      5.9      )  ]  \n *  Pulmonary Toxicity [see  Warnings and Precautions (5.10)  ]  \n *  Serious Dermatologic Reactions [see  Warnings and Precautions (5.11)    ]   \n      EXCERPT:   The most common adverse reactions (>=20%) were:\n \n\n *  Relapsed classical HL and relapsed sALCL: neutropenia, peripheral sensory neuropathy, fatigue, nausea, anemia, upper respiratory tract infection, diarrhea, pyrexia, rash, thrombocytopenia, cough, and vomiting  (6.1)  . \n *  Classical HL post-auto-HSCT consolidation: neutropenia, peripheral sensory neuropathy, thrombocytopenia, anemia, upper respiratory tract infection, fatigue, peripheral motor neuropathy, nausea, cough, and diarrhea  (6.1)  . \n      To report SUSPECTED ADVERSE REACTIONS, contact Seattle Genetics, Inc. at 1-855-473-2436 or FDA at 1-800-FDA-1088 or www.fda.gov/medwatch.  \n \n\n \n\n  6.1 Clinical Trial Experience\n\n  Because clinical trials are conducted under widely varying conditions, adverse reaction rates observed in clinical trials of a drug cannot be directly compared to rates in the clinical trials of another drug and may not reflect the rates observed in practice.\n\n\n\n The data below reflect exposure to ADCETRIS as monotherapy in 327 patients with classical Hodgkin lymphoma (HL) and systemic anaplastic large cell lymphoma (sALCL), including 160 patients in two uncontrolled single-arm trials (Studies 1 and 2) and 167 patients in one placebo-controlled randomized trial (Study 3).\n\n\n\n In Studies 1 and 2, the most common adverse reactions (>=20%), regardless of causality, were neutropenia, peripheral sensory neuropathy, fatigue, nausea, anemia, upper respiratory tract infection, diarrhea, pyrexia, rash, thrombocytopenia, cough, and vomiting. The most common adverse reactions occurring in at least 10% of patients in either Study 1 or 2, regardless of causality, using the NCI Common Toxicity Criteria (CTC) Version 3.0, are shown in   Table 2  .\n\n\n\n In Study 3, the most common adverse reactions (>=20%) in the ADCETRIS-treatment arm, regardless of causality, were neutropenia, peripheral sensory neuropathy, thrombocytopenia, anemia, upper respiratory tract infection, fatigue, peripheral motor neuropathy, nausea, cough, and diarrhea. The most common adverse reactions occurring in at least 10% of patients, using the NCI CTC Version 4, are shown in  Table 3  .\n\n\n\n   Experience in Classical Hodgkin Lymphoma  \n\n\n\n     Summary of Clinical Trial Experience in Relapsed Classical HL (Study 1)    \n\n\n\n ADCETRIS was studied in 102 patients with classical HL in a single arm clinical trial in which the recommended starting dose and schedule was 1.8 mg/kg intravenously every 3 weeks. Median duration of treatment was 9 cycles (range, 1-16)  [see  Clinical Studies (        14.1        )  ]  .\n\n\n\n The most common adverse reactions (>=20%), regardless of causality, were neutropenia, peripheral sensory neuropathy, fatigue, upper respiratory tract infection, nausea,  ...

# %%
X['S1'][236:(236+11)]
# Out:
# u'Anaphylaxis'

# %%
Y[:2]
# Out:
# [{'id': u'M1',
#   'len': u'21',
#   'section': u'S1',
#   'start': u'156',
#   'text': u'Peripheral Neuropathy',
#   'type': u'AdverseReaction'},
#  {'id': u'M2',
#   'len': u'11',
#   'section': u'S1',
#   'start': u'236',
#   'text': u'Anaphylaxis',
#   'type': u'AdverseReaction'}]

# %% [markdown]
# ### For NER_DL: extract only the entities and tags in training folder (then use the pre-trained word2vec from spacy)

# %%
f = path + 'ADCETRIS.xml'
X, Y = parse_xml(f)
X.keys()
# Out:
# [u'S3', u'S2', u'S1']

# %%
doc = X['S1']
words = [[m.group(0), m.start(), m.end(), 'O'] for m in re.finditer(r'\w+', doc)
        if m.group(0) ]
words
# Out:
# [[u'6', 4, 5, 'O'],
#  [u'ADVERSE', 6, 13, 'O'],
#  [u'REACTIONS', 14, 23, 'O'],
#  [u'The', 27, 30, 'O'],
#  [u'following', 31, 40, 'O'],
#  [u'serious', 41, 48, 'O'],
#  [u'adverse', 49, 56, 'O'],
#  [u'reactions', 57, 66, 'O'],
#  [u'are', 67, 70, 'O'],
#  [u'discussed', 71, 80, 'O'],
#  [u'in', 81, 83, 'O'],
#  [u'greater', 84, 91, 'O'],
#  [u'detail', 92, 98, 'O'],
#  [u'in', 99, 101, 'O'],
#  [u'other', 102, 107, 'O'],
#  [u'sections', 108, 116, 'O'],
#  [u'of', 117, 119, 'O'],
#  [u'the', 120, 123, 'O'],
#  [u'prescribing', 124, 135, 'O'],
#  [u'information', 136, 147, 'O'],
#  [u'Peripheral', 156, 166, 'O'],
#  [u'Neuropathy', 167, 177, 'O'],
#  [u'see', 179, 182, 'O'],
#  [u'Warnings', 184, 192, 'O'],
#  [u'and', 193, 196, 'O'],
#  [u'Precautions', 197, 208, 'O'],
#  [u'5', 216, 217, 'O'],
#  [u'1', 218, 219, 'O'],
#  [u'Anaphylaxis', 236, 247, 'O'],
#  [u'and', 248, 251, 'O'],
#  [u'Infusion', 252, 260, 'O'],
#  [u'Reactions', 261, 270, 'O'],
#  [u'see', 272, 275, 'O'],
#  [u'Warnings', 277, 285, 'O'],
#  [u'and', 286, 289, 'O'],
#  [u'Precautions', 290, 301, 'O'],
#  [u'5', 309, 310, 'O'],
#  [u'2', 311, 312, 'O'],
#  [u'Hematologic', 329, 340, 'O'],
#  [u'Toxicities', 341, 351, 'O'],
#  [u'see', 353, 356, 'O'],
#  [u'Warnings', 358, 366, 'O'],
#  [u'and', 367, 370, 'O'],
#  [u'Precautions', 371, 382, 'O'],
#  [u'5', 390, 391, 'O'],
#  [u'3', 392, 393, 'O'],
#  [u'Serious', 410, 417, 'O'],
#  [u'Infections', 418, 428, 'O'],
#  [u'and', 429, 432, 'O'],
#  [u'Opportunistic', 433, 446, 'O'],
#  [u'Infections', 447, 457, 'O'],
#  [u'see', 459, 462, 'O'],
#  [u'Warnings', 464, 472, 'O'],
#  [u'and', 473, 476, 'O'],
#  [u'Precautions', 477, 488, 'O'],
#  [u'5', 496, 497, 'O'],
#  [u'4', 498, 499, 'O'],
#  [u'Tumor', 516, 521, 'O'],
#  [u'Lysis', 522, 527, 'O'],
#  [u'Syndrome', 528, 536, 'O'],
#  [u'see', 538, 541, 'O'],
#  [u'Warnings', 543, 551, 'O'],
#  [u'and', 552, 555, 'O'],
#  [u'Precautions', 556, 567, 'O'],
#  [u'5', 575, 576, 'O'],
#  [u'5', 577, 578, 'O'],
#  [u'Increased', 595, 604, 'O'],
#  [u'Toxicity', 605, 613, 'O'],
#  [u'in', 614, 616, 'O'],
#  [u'the', 617, 620, 'O'],
#  [u'Presence', 621, 629, 'O'],
#  [u'of', 630, 632, 'O'],
#  [u'Severe', 633, 639, 'O'],
#  [u'Renal', 640, 645, 'O'],
#  [u'Impairment', 646, 656, 'O'],
#  [u'see', 658, 661, 'O'],
#  [u'Warnings', 663, 671, 'O'],
#  [u'and', 672, 675, 'O'],
#  [u'Precautions', 676, 687, 'O'],
#  [u'5', 695, 696, 'O'],
#  [u'6', 697, 698, 'O'],
#  [u'Increased', 715, 724, 'O'],
#  [u'Toxicity', 725, 733, 'O'],
#  [u'in', 734, 736, 'O'],
#  [u'the', 737, 740, 'O'],
#  [u'Presence', 741, 749, 'O'],
#  [u'of', 750, 752, 'O'],
#  [u'Moderate', 753, 761, 'O'],
#  [u'or', 762, 764, 'O'],
#  [u'Severe', 765, 771, 'O'],
#  [u'Hepatic', 772, 779, 'O'],
#  [u'Impairment', 780, 790, 'O'],
#  [u'see', 792, 795, 'O'],
#  [u'Warnings', 797, 805, 'O'],
#  [u'and', 806, 809, 'O'],
#  [u'Precautions', 810, 821, 'O'],
#  [u'5', 829, 830, 'O'],
#  [u'7', 831, 832, 'O'],
#  [u'Hepatotoxicity', 849, 863, 'O'],
#  [u'see', 865, 868, 'O'],
#  [u'Warnings', 870, 878, 'O'],
#  [u'and', 879, 882, 'O'],
#  [u'Precautions', 883, 894, 'O'],
#  [u'5', 902, 903, 'O'],
#  [u'8', 904, 905, 'O'],
#  [u'Progressive', 922, 933, 'O'],
#  [u'Multifocal', 934, 944, 'O'],
#  [u'Leukoencephalopathy', 945, 964, 'O'],
#  [u'see', 966, 969, 'O'],
#  [u'Warnings', 971, 979, 'O'],
#  [u'and', 980, 983, 'O'],
#  [u'Precautions', 984, 995, 'O'],
#  [u'5', 1003, 1004, 'O'],
#  [u'9', 1005, 1006, 'O'],
#  [u'Pulmonary', 1023, 1032, 'O'],
#  [u'Toxicity', 1033, 1041, 'O'],
#  [u'see', 1043, 1046, 'O'],
#  [u'Warnings', 1048, 1056, 'O'],
#  [u'and', 1057, 1060, 'O'],
#  [u'Precautions', 1061, 1072, 'O'],
#  [u'5', 1074, 1075, 'O'],
#  [u'10', 1076, 1078, 'O'],
#  [u'Serious', 1089, 1096, 'O'],
#  [u'Dermatologic', 1097, 1109, 'O'],
#  [u'Reactions', 1110, 1119, 'O'],
#  [u'see', 1121, 1124, 'O'],
#  [u'Warnings', 1126, 1134, 'O'],
#  [u'and', 1135, 1138, 'O'],
#  [u'Precautions', 1139, 1150, 'O'],
#  [u'5', 1152, 1153, 'O'],
#  [u'11', 1154, 1156, 'O'],
#  [u'EXCERPT', 1172, 1179, 'O'],
#  [u'The', 1183, 1186, 'O'],
#  [u'most', 1187, 1191, 'O'],
#  [u'common', 1192, 1198, 'O'],
#  [u'adverse', 1199, 1206, 'O'],
#  [u'reactions', 1207, 1216, 'O'],
#  [u'20', 1220, 1222, 'O'],
#  [u'were', 1225, 1229, 'O'],
#  [u'Relapsed', 1238, 1246, 'O'],
#  [u'classical', 1247, 1256, 'O'],
#  [u'HL', 1257, 1259, 'O'],
#  [u'and', 1260, 1263, 'O'],
#  [u'relapsed', 1264, 1272, 'O'],
#  [u'sALCL', 1273, 1278, 'O'],
#  [u'neutropenia', 1280, 1291, 'O'],
#  [u'peripheral', 1293, 1303, 'O'],
#  [u'sensory', 1304, 1311, 'O'],
#  [u'neuropathy', 1312, 1322, 'O'],
#  [u'fatigue', 1324, 1331, 'O'],
#  [u'nausea', 1333, 1339, 'O'],
#  [u'anemia', 1341, 1347, 'O'],
#  [u'upper', 1349, 1354, 'O'],
#  [u'respiratory', 1355, 1366, 'O'],
#  [u'tract', 1367, 1372, 'O'],
#  [u'infection', 1373, 1382, 'O'],
#  [u'diarrhea', 1384, 1392, 'O'],
#  [u'pyrexia', 1394, 1401, 'O'],
#  [u'rash', 1403, 1407, 'O'],
#  [u'thrombocytopenia', 1409, 1425, 'O'],
#  [u'cough', 1427, 1432, 'O'],
#  [u'and', 1434, 1437, 'O'],
#  [u'vomiting', 1438, 1446, 'O'],
#  [u'6', 1449, 1450, 'O'],
#  [u'1', 1451, 1452, 'O'],
#  [u'Classical', 1462, 1471, 'O'],
#  [u'HL', 1472, 1474, 'O'],
#  [u'post', 1475, 1479, 'O'],
#  [u'auto', 1480, 1484, 'O'],
#  [u'HSCT', 1485, 1489, 'O'],
#  [u'consolidation', 1490, 1503, 'O'],
#  [u'neutropenia', 1505, 1516, 'O'],
#  [u'peripheral', 1518, 1528, 'O'],
#  [u'sensory', 1529, 1536, 'O'],
#  [u'neuropathy', 1537, 1547, 'O'],
#  [u'thrombocytopenia', 1549, 1565, 'O'],
#  [u'anemia', 1567, 1573, 'O'],
#  [u'upper', 1575, 1580, 'O'],
#  [u'respiratory', 1581, 1592, 'O'],
#  [u'tract', 1593, 1598, 'O'],
#  [u'infection', 1599, 1608, 'O'],
#  [u'fatigue', 1610, 1617, 'O'],
#  [u'peripheral', 1619, 1629, 'O'],
#  [u'motor', 1630, 1635, 'O'],
#  [u'neuropathy', 1636, 1646, 'O'],
#  [u'nausea', 1648, 1654, 'O'],
#  [u'cough', 1656, 1661, 'O'],
#  [u'and', 1663, 1666, 'O'],
#  [u'diarrhea', 1667, 1675, 'O'],
#  [u'6', 1678, 1679, 'O'],
#  [u'1', 1680, 1681, 'O'],
#  [u'To', 1693, 1695, 'O'],
#  [u'report', 1696, 1702, 'O'],
#  [u'SUSPECTED', 1703, 1712, 'O'],
#  [u'ADVERSE', 1713, 1720, 'O'],
#  [u'REACTIONS', 1721, 1730, 'O'],
#  [u'contact', 1732, 1739, 'O'],
#  [u'Seattle', 1740, 1747, 'O'],
#  [u'Genetics', 1748, 1756, 'O'],
#  [u'Inc', 1758, 1761, 'O'],
#  [u'at', 1763, 1765, 'O'],
#  [u'1', 1766, 1767, 'O'],
#  [u'855', 1768, 1771, 'O'],
#  [u'473', 1772, 1775, 'O'],
#  [u'2436', 1776, 1780, 'O'],
#  [u'or', 1781, 1783, 'O'],
#  [u'FDA', 1784, 1787, 'O'],
#  [u'at', 1788, 1790, 'O'],
#  [u'1', 1791, 1792, 'O'],
#  [u'800', 1793, 1796, 'O'],
#  [u'FDA', 1797, 1800, 'O'],
#  [u'1088', 1801, 1805, 'O'],
#  [u'or', 1806, 1808, 'O'],
#  [u'www', 1809, 1812, 'O'],
#  [u'fda', 1813, 1816, 'O'],
#  [u'gov', 1817, 1820, 'O'],
#  [u'medwatch', 1821, 1829, 'O'],
#  [u'6', 1841, 1842, 'O'],
#  [u'1', 1843, 1844, 'O'],
#  [u'Clinical', 1845, 1853, 'O'],
#  [u'Trial', 1854, 1859, 'O'],
#  [u'Experience', 1860, 1870, 'O'],
#  [u'Because', 1874, 1881, 'O'],
#  [u'clinical', 1882, 1890, 'O'],
#  [u'trials', 1891, 1897, 'O'],
#  [u'are', 1898, 1901, 'O'],
#  [u'conducted', 1902, 1911, 'O'],
#  [u'under', 1912, 1917, 'O'],
#  [u'widely', 1918, 1924, 'O'],
#  [u'varying', 1925, 1932, 'O'],
#  [u'conditions', 1933, 1943, 'O'],
#  [u'adverse', 1945, 1952, 'O'],
#  [u'reaction', 1953, 1961, 'O'],
#  [u'rates', 1962, 1967, 'O'],
#  [u'observed', 1968, 1976, 'O'],
#  [u'in', 1977, 1979, 'O'],
#  [u'clinical', 1980, 1988, 'O'],
#  [u'trials', 1989, 1995, 'O'],
#  [u'of', 1996, 1998, 'O'],
#  [u'a', 1999, 2000, 'O'],
#  [u'drug', 2001, 2005, 'O'],
#  [u'cannot', 2006, 2012, 'O'],
#  [u'be', 2013, 2015, 'O'],
#  [u'directly', 2016, 2024, 'O'],
#  [u'compared', 2025, 2033, 'O'],
#  [u'to', 2034, 2036, 'O'],
#  [u'rates', 2037, 2042, 'O'],
#  [u'in', 2043, 2045, 'O'],
#  [u'the', 2046, 2049, 'O'],
#  [u'clinical', 2050, 2058, 'O'],
#  [u'trials', 2059, 2065, 'O'],
#  [u'of', 2066, 2068, 'O'],
#  [u'another', 2069, 2076, 'O'],
#  [u'drug', 2077, 2081, 'O'],
#  [u'and', 2082, 2085, 'O'],
#  [u'may', 2086, 2089, 'O'],
#  [u'not', 2090, 2093, 'O'],
#  [u'reflect', 2094, 2101, 'O'],
#  [u'the', 2102, 2105, 'O'],
#  [u'rates', 2106, 2111, 'O'],
#  [u'observed', 2112, 2120, 'O'],
#  [u'in', 2121, 2123, 'O'],
#  [u'practice', 2124, 2132, 'O'],
#  [u'The', 2138, 2141, 'O'],
#  [u'data', 2142, 2146, 'O'],
#  [u'below', 2147, 2152, 'O'],
#  [u'reflect', 2153, 2160, 'O'],
#  [u'exposure', 2161, 2169, 'O'],
#  [u'to', 2170, 2172, 'O'],
#  [u'ADCETRIS', 2173, 2181, 'O'],
#  [u'as', 2182, 2184, 'O'],
#  [u'monotherapy', 2185, 2196, 'O'],
#  [u'in', 2197, 2199, 'O'],
#  [u'327', 2200, 2203, 'O'],
#  [u'patients', 2204, 2212, 'O'],
#  [u'with', 2213, 2217, 'O'],
#  [u'classical', 2218, 2227, 'O'],
#  [u'Hodgkin', 2228, 2235, 'O'],
#  [u'lymphoma', 2236, 2244, 'O'],
#  [u'HL', 2246, 2248, 'O'],
#  [u'and', 2250, 2253, 'O'],
#  [u'systemic', 2254, 2262, 'O'],
#  [u'anaplastic', 2263, 2273, 'O'],
#  [u'large', 2274, 2279, 'O'],
#  [u'cell', 2280, 2284, 'O'],
#  [u'lymphoma', 2285, 2293, 'O'],
#  [u'sALCL', 2295, 2300, 'O'],
#  [u'including', 2303, 2312, 'O'],
#  [u'160', 2313, 2316, 'O'],
#  [u'patients', 2317, 2325, 'O'],
#  [u'in', 2326, 2328, 'O'],
#  [u'two', 2329, 2332, 'O'],
#  [u'uncontrolled', 2333, 2345, 'O'],
#  [u'single', 2346, 2352, 'O'],
#  [u'arm', 2353, 2356, 'O'],
#  [u'trials', 2357, 2363, 'O'],
#  [u'Studies', 2365, 2372, 'O'],
#  [u'1', 2373, 2374, 'O'],
#  [u'and', 2375, 2378, 'O'],
#  [u'2', 2379, 2380, 'O'],
#  [u'and', 2382, 2385, 'O'],
#  [u'167', 2386, 2389, 'O'],
#  [u'patients', 2390, 2398, 'O'],
#  [u'in', 2399, 2401, 'O'],
#  [u'one', 2402, 2405, 'O'],
#  [u'placebo', 2406, 2413, 'O'],
#  [u'controlled', 2414, 2424, 'O'],
#  [u'randomized', 2425, 2435, 'O'],
#  [u'trial', 2436, 2441, 'O'],
#  [u'Study', 2443, 2448, 'O'],
#  [u'3', 2449, 2450, 'O'],
#  [u'In', 2457, 2459, 'O'],
#  [u'Studies', 2460, 2467, 'O'],
#  [u'1', 2468, 2469, 'O'],
#  [u'and', 2470, 2473, 'O'],
#  [u'2', 2474, 2475, 'O'],
#  [u'the', 2477, 2480, 'O'],
#  [u'most', 2481, 2485, 'O'],
#  [u'common', 2486, 2492, 'O'],
#  [u'adverse', 2493, 2500, 'O'],
#  [u'reactions', 2501, 2510, 'O'],
#  [u'20', 2514, 2516, 'O'],
#  [u'regardless', 2520, 2530, 'O'],
#  [u'of', 2531, 2533, 'O'],
#  [u'causality', 2534, 2543, 'O'],
#  [u'were', 2545, 2549, 'O'],
#  [u'neutropenia', 2550, 2561, 'O'],
#  [u'peripheral', 2563, 2573, 'O'],
#  [u'sensory', 2574, 2581, 'O'],
#  [u'neuropathy', 2582, 2592, 'O'],
#  [u'fatigue', 2594, 2601, 'O'],
#  [u'nausea', 2603, 2609, 'O'],
#  [u'anemia', 2611, 2617, 'O'],
#  [u'upper', 2619, 2624, 'O'],
#  [u'respiratory', 2625, 2636, 'O'],
#  [u'tract', 2637, 2642, 'O'],
#  [u'infection', 2643, 2652, 'O'],
#  [u'diarrhea', 2654, 2662, 'O'],
#  [u'pyrexia', 2664, 2671, 'O'],
#  [u'rash', 2673, 2677, 'O'],
#  [u'thrombocytopenia', 2679, 2695, 'O'],
#  [u'cough', 2697, 2702, 'O'],
#  [u'and', 2704, 2707, 'O'],
#  [u'vomiting', 2708, 2716, 'O'],
#  [u'The', 2718, 2721, 'O'],
#  [u'most', 2722, 2726, 'O'],
#  [u'common', 2727, 2733, 'O'],
#  [u'adverse', 2734, 2741, 'O'],
#  [u'reactions', 2742, 2751, 'O'],
#  [u'occurring', 2752, 2761, 'O'],
#  [u'in', 2762, 2764, 'O'],
#  [u'at', 2765, 2767, 'O'],
#  [u'least', 2768, 2773, 'O'],
#  [u'10', 2774, 2776, 'O'],
#  [u'of', 2778, 2780, 'O'],
#  [u'patients', 2781, 2789, 'O'],
#  [u'in', 2790, 2792, 'O'],
#  [u'either', 2793, 2799, 'O'],
#  [u'Study', 2800, 2805, 'O'],
#  [u'1', 2806, 2807, 'O'],
#  [u'or', 2808, 2810, 'O'],
#  [u'2', 2811, 2812, 'O'],
#  [u'regardless', 2814, 2824, 'O'],
#  [u'of', 2825, 2827, 'O'],
#  [u'causality', 2828, 2837, 'O'],
#  [u'using', 2839, 2844, 'O'],
#  [u'the', 2845, 2848, 'O'],
#  [u'NCI', 2849, 2852, 'O'],
#  [u'Common', 2853, 2859, 'O'],
#  [u'Toxicity', 2860, 2868, 'O'],
#  [u'Criteria', 2869, 2877, 'O'],
#  [u'CTC', 2879, 2882, 'O'],
#  [u'Version', 2884, 2891, 'O'],
#  [u'3', 2892, 2893, 'O'],
#  [u'0', 2894, 2895, 'O'],
#  [u'are', 2897, 2900, 'O'],
#  [u'shown', 2901, 2906, 'O'],
#  [u'in', 2907, 2909, 'O'],
#  [u'Table', 2912, 2917, 'O'],
#  [u'2', 2918, 2919, 'O'],
#  [u'In', 2927, 2929, 'O'],
#  [u'Study', 2930, 2935, 'O'],
#  [u'3', 2936, 2937, 'O'],
#  [u'the', 2939, 2942, 'O'],
#  [u'most', 2943, 2947, 'O'],
#  [u'common', 2948, 2954, 'O'],
#  [u'adverse', 2955, 2962, 'O'],
#  [u'reactions', 2963, 2972, 'O'],
#  [u'20', 2976, 2978, 'O'],
#  [u'in', 2981, 2983, 'O'],
#  [u'the', 2984, 2987, 'O'],
#  [u'ADCETRIS', 2988, 2996, 'O'],
#  [u'treatment', 2997, 3006, 'O'],
#  [u'arm', 3007, 3010, 'O'],
#  [u'regardless', 3012, 3022, 'O'],
#  [u'of', 3023, 3025, 'O'],
#  [u'causality', 3026, 3035, 'O'],
#  [u'were', 3037, 3041, 'O'],
#  [u'neutropenia', 3042, 3053, 'O'],
#  [u'peripheral', 3055, 3065, 'O'],
#  [u'sensory', 3066, 3073, 'O'],
#  [u'neuropathy', 3074, 3084, 'O'],
#  [u'thrombocytopenia', 3086, 3102, 'O'],
#  [u'anemia', 3104, 3110, 'O'],
#  [u'upper', 3112, 3117, 'O'],
#  [u'respiratory', 3118, 3129, 'O'],
#  [u'tract', 3130, 3135, 'O'],
#  [u'infection', 3136, 3145, 'O'],
#  [u'fatigue', 3147, 3154, 'O'],
#  [u'peripheral', 3156, 3166, 'O'],
#  [u'motor', 3167, 3172, 'O'],
#  [u'neuropathy', 3173, 3183, 'O'],
#  [u'nausea', 3185, 3191, 'O'],
#  [u'cough', 3193, 3198, 'O'],
#  [u'and', 3200, 3203, 'O'],
#  [u'diarrhea', 3204, 3212, 'O'],
#  [u'The', 3214, 3217, 'O'],
#  [u'most', 3218, 3222, 'O'],
#  [u'common', 3223, 3229, 'O'],
#  [u'adverse', 3230, 3237, 'O'],
#  [u'reactions', 3238, 3247, 'O'],
#  [u'occurring', 3248, 3257, 'O'],
#  [u'in', 3258, 3260, 'O'],
#  [u'at', 3261, 3263, 'O'],
#  [u'least', 3264, 3269, 'O'],
#  [u'10', 3270, 3272, 'O'],
#  [u'of', 3274, 3276, 'O'],
#  [u'patients', 3277, 3285, 'O'],
#  [u'using', 3287, 3292, 'O'],
#  [u'the', 3293, 3296, 'O'],
#  [u'NCI', 3297, 3300, 'O'],
#  [u'CTC', 3301, 3304, 'O'],
#  [u'Version', 3305, 3312, 'O'],
#  [u'4', 3313, 3314, 'O'],
#  [u'are', 3316, 3319, 'O'],
#  [u'shown', 3320, 3325, 'O'],
#  [u'in', 3326, 3328, 'O'],
#  [u'Table', 3330, 3335, 'O'],
#  [u'3', 3336, 3337, 'O'],
#  [u'Experience', 3347, 3357, 'O'],
#  [u'in', 3358, 3360, 'O'],
#  [u'Classical', 3361, 3370, 'O'],
#  [u'Hodgkin', 3371, 3378, 'O'],
#  [u'Lymphoma', 3379, 3387, 'O'],
#  [u'Summary', 3398, 3405, 'O'],
#  [u'of', 3406, 3408, 'O'],
#  [u'Clinical', 3409, 3417, 'O'],
#  [u'Trial', 3418, 3423, 'O'],
#  [u'Experience', 3424, 3434, 'O'],
#  [u'in', 3435, 3437, 'O'],
#  [u'Relapsed', 3438, 3446, 'O'],
#  [u'Classical', 3447, 3456, 'O'],
#  [u'HL', 3457, 3459, 'O'],
#  [u'Study', 3461, 3466, 'O'],
#  [u'1', 3467, 3468, 'O'],
#  [u'ADCETRIS', 3478, 3486, 'O'],
#  [u'was', 3487, 3490, 'O'],
#  [u'studied', 3491, 3498, 'O'],
#  [u'in', 3499, 3501, 'O'],
#  [u'102', 3502, 3505, 'O'],
#  [u'patients', 3506, 3514, 'O'],
#  [u'with', 3515, 3519, 'O'],
#  [u'classical', 3520, 3529, 'O'],
#  [u'HL', 3530, 3532, 'O'],
#  [u'in', 3533, 3535, 'O'],
#  [u'a', 3536, 3537, 'O'],
#  [u'single', 3538, 3544, 'O'],
#  [u'arm', 3545, 3548, 'O'],
#  [u'clinical', 3549, 3557, 'O'],
#  [u'trial', 3558, 3563, 'O'],
#  [u'in', 3564, 3566, 'O'],
#  [u'which', 3567, 3572, 'O'],
#  [u'the', 3573, 3576, 'O'],
#  [u'recommended', 3577, 3588, 'O'],
#  [u'starting', 3589, 3597, 'O'],
#  [u'dose', 3598, 3602, 'O'],
#  [u'and', 3603, 3606, 'O'],
#  [u'schedule', 3607, 3615, 'O'],
#  [u'was', 3616, 3619, 'O'],
#  [u'1', 3620, 3621, 'O'],
#  [u'8', 3622, 3623, 'O'],
#  [u'mg', 3624, 3626, 'O'],
#  [u'kg', 3627, 3629, 'O'],
#  [u'intravenously', 3630, 3643, 'O'],
#  [u'every', 3644, 3649, 'O'],
#  [u'3', 3650, 3651, 'O'],
#  [u'weeks', 3652, 3657, 'O'],
#  [u'Median', 3659, 3665, 'O'],
#  [u'duration', 3666, 3674, 'O'],
#  [u'of', 3675, 3677, 'O'],
#  [u'treatment', 3678, 3687, 'O'],
#  [u'was', 3688, 3691, 'O'],
#  [u'9', 3692, 3693, 'O'],
#  [u'cycles', 3694, 3700, 'O'],
#  [u'range', 3702, 3707, 'O'],
#  [u'1', 3709, 3710, 'O'],
#  [u'16', 3711, 3713, 'O'],
#  [u'see', 3717, 3720, 'O'],
#  [u'Clinical', 3722, 3730, 'O'],
#  [u'Studies', 3731, 3738, 'O'],
#  [u'14', 3748, 3750, 'O'],
#  [u'1', 3751, 3752, 'O'],
#  [u'The', 3772, 3775, 'O'],
#  [u'most', 3776, 3780, 'O'],
#  [u'common', 3781, 3787, 'O'],
#  [u'adverse', 3788, 3795, 'O'],
#  [u'reactions', 3796, 3805, 'O'],
#  [u'20', 3809, 3811, 'O'],
#  [u'regardless', 3815, 3825, 'O'],
#  [u'of', 3826, 3828, 'O'],
#  [u'causality', 3829, 3838, 'O'],
#  [u'were', 3840, 3844, 'O'],
#  [u'neutropenia', 3845, 3856, 'O'],
#  [u'peripheral', 3858, 3868, 'O'],
#  [u'sensory', 3869, 3876, 'O'],
#  [u'neuropathy', 3877, 3887, 'O'],
#  [u'fatigue', 3889, 3896, 'O'],
#  [u'upper', 3898, 3903, 'O'],
#  [u'respiratory', 3904, 3915, 'O'],
#  [u'tract', 3916, 3921, 'O'],
#  [u'infection', 3922, 3931, 'O'],
#  [u'nausea', 3933, 3939, 'O'],
#  [u'diarrhea', 3941, 3949, 'O'],
#  [u'anemia', 3951, 3957, 'O'],
#  [u'pyrexia', 3959, 3966, 'O'],
#  [u'thrombocytopenia', 3968, 3984, 'O'],
#  [u'rash', 3986, 3990, 'O'],
#  [u'abdominal', 3992, 4001, 'O'],
#  [u'pain', 4002, 4006, 'O'],
#  [u'cough', 4008, 4013, 'O'],
#  [u'and', 4015, 4018, 'O'],
#  [u'vomiting', 4019, 4027, 'O'],
#  [u'Summary', 4037, 4044, 'O'],
#  [u'of', 4045, 4047, 'O'],
#  [u'Clinical', 4048, 4056, 'O'],
#  [u'Trial', 4057, 4062, 'O'],
#  [u'Experience', 4063, 4073, 'O'],
#  [u'in', 4074, 4076, 'O'],
#  [u'Classical', 4077, 4086, 'O'],
#  [u'HL', 4087, 4089, 'O'],
#  [u'Post', 4090, 4094, 'O'],
#  [u'auto', 4095, 4099, 'O'],
#  [u'HSCT', 4100, 4104, 'O'],
#  [u'Consolidation', 4105, 4118, 'O'],
#  [u'Study', 4120, 4125, 'O'],
#  [u'3', 4126, 4127, 'O'],
#  [u'ADCETRIS', 4137, 4145, 'O'],
#  [u'was', 4146, 4149, 'O'],
#  [u'studied', 4150, 4157, 'O'],
#  [u'in', 4158, 4160, 'O'],
#  [u'329', 4161, 4164, 'O'],
#  [u'patients', 4165, 4173, 'O'],
#  [u'with', 4174, 4178, 'O'],
#  [u'classical', 4179, 4188, 'O'],
#  [u'HL', 4189, 4191, 'O'],
#  [u'at', 4192, 4194, 'O'],
#  [u'high', 4195, 4199, 'O'],
#  [u'risk', 4200, 4204, 'O'],
#  [u'of', 4205, 4207, 'O'],
#  [u'relapse', 4208, 4215, 'O'],
#  [u'or', 4216, 4218, 'O'],
#  [u'progression', 4219, 4230, 'O'],
#  [u'post', 4231, 4235, 'O'],
#  [u'auto', 4236, 4240, 'O'],
#  [u'HSCT', 4241, 4245, 'O'],
#  [u'in', 4246, 4248, 'O'],
#  [u'a', 4249, 4250, 'O'],
#  [u'randomized', 4251, 4261, 'O'],
#  [u'double', 4263, 4269, 'O'],
#  [u'blind', 4270, 4275, 'O'],
#  [u'placebo', 4277, 4284, 'O'],
#  [u'controlled', 4285, 4295, 'O'],
#  [u'clinical', 4296, 4304, 'O'],
#  [u'trial', 4305, 4310, 'O'],
#  [u'in', 4311, 4313, 'O'],
#  [u'which', 4314, 4319, 'O'],
#  [u'the', 4320, 4323, 'O'],
#  [u'recommended', 4324, 4335, 'O'],
#  [u'starting', 4336, 4344, 'O'],
#  [u'dose', 4345, 4349, 'O'],
#  [u'and', 4350, 4353, 'O'],
#  [u'schedule', 4354, 4362, 'O'],
#  [u'was', 4363, 4366, 'O'],
#  [u'1', 4367, 4368, 'O'],
#  [u'8', 4369, 4370, 'O'],
#  [u'mg', 4371, 4373, 'O'],
#  [u'kg', 4374, 4376, 'O'],
#  [u'of', 4377, 4379, 'O'],
#  [u'ADCETRIS', 4380, 4388, 'O'],
#  [u'administered', 4389, 4401, 'O'],
#  [u'intravenously', 4402, 4415, 'O'],
#  [u'over', 4416, 4420, 'O'],
#  [u'30', 4421, 4423, 'O'],
#  [u'minutes', 4424, 4431, 'O'],
#  [u'every', 4432, 4437, 'O'],
#  [u'3', 4438, 4439, 'O'],
#  [u'weeks', 4440, 4445, 'O'],
#  [u'or', 4446, 4448, 'O'],
#  [u'placebo', 4449, 4456, 'O'],
#  [u'for', 4457, 4460, 'O'],
#  [u'up', 4461, 4463, 'O'],
#  [u'to', 4464, 4466, 'O'],
#  [u'16', 4467, 4469, 'O'],
#  [u'cycles', 4470, 4476, 'O'],
#  [u'Of', 4478, 4480, 'O'],
#  [u'the', 4481, 4484, 'O'],
#  [u'329', 4485, 4488, 'O'],
#  [u'enrolled', 4489, 4497, 'O'],
#  [u'patients', 4498, 4506, 'O'],
#  [u'327', 4508, 4511, 'O'],
#  [u'167', 4513, 4516, 'O'],
#  [u'brentuximab', 4517, 4528, 'O'],
#  [u'vedotin', 4529, 4536, 'O'],
#  [u'160', 4538, 4541, 'O'],
#  [u'placebo', 4542, 4549, 'O'],
#  [u'received', 4551, 4559, 'O'],
#  [u'at', 4560, 4562, 'O'],
#  [u'least', 4563, 4568, 'O'],
#  [u'one', 4569, 4572, 'O'],
#  [u'dose', 4573, 4577, 'O'],
#  [u'of', 4578, 4580, 'O'],
#  [u'study', 4581, 4586, 'O'],
#  [u'treatment', 4587, 4596, 'O'],
#  [u'The', 4598, 4601, 'O'],
#  [u'median', 4602, 4608, 'O'],
#  [u'number', 4609, 4615, 'O'],
#  [u'of', 4616, 4618, 'O'],
#  [u'treatment', 4619, 4628, 'O'],
#  [u'cycles', 4629, 4635, 'O'],
#  [u'in', 4636, 4638, 'O'],
#  [u'each', 4639, 4643, 'O'],
#  [u'study', 4644, 4649, 'O'],
#  [u'arm', 4650, 4653, 'O'],
#  [u'was', 4654, 4657, 'O'],
#  [u'15', 4658, 4660, 'O'],
#  [u'range', 4662, 4667, 'O'],
#  [u'1', 4669, 4670, 'O'],
#  [u'16', 4671, 4673, 'O'],
#  [u'and', 4675, 4678, 'O'],
#  [u'80', 4679, 4681, 'O'],
#  [u'patients', 4682, 4690, 'O'],
#  [u'48', 4692, 4694, 'O'],
#  [u'in', 4697, 4699, 'O'],
#  [u'the', 4700, 4703, 'O'],
#  [u'ADCETRIS', 4704, 4712, 'O'],
#  [u'treatment', 4713, 4722, 'O'],
#  [u'arm', 4723, 4726, 'O'],
#  [u'received', 4727, 4735, 'O'],
#  [u'16', 4736, 4738, 'O'],
#  [u'cycles', 4739, 4745, 'O'],
#  [u'see', 4748, 4751, 'O'],
#  [u'Clinical', 4753, 4761, 'O'],
#  [u'Studies', 4762, 4769, 'O'],
#  [u'14', 4779, 4781, 'O'],
#  [u'1', 4782, 4783, 'O'],
#  [u'Standard', 4803, 4811, 'O'],
#  [u'international', 4812, 4825, 'O'],
#  [u'guidelines', 4826, 4836, 'O'],
#  [u'were', 4837, 4841, 'O'],
#  [u'followed', 4842, 4850, 'O'],
#  [u'for', 4851, 4854, 'O'],
#  [u'infection', 4855, 4864, 'O'],
#  [u'prophylaxis', 4865, 4876, 'O'],
#  [u'for', 4877, 4880, 'O'],
#  [u'herpes', 4881, 4887, 'O'],
#  [u'simplex', 4888, 4895, 'O'],
#  [u'virus', 4896, 4901, 'O'],
#  [u'HSV', 4903, 4906, 'O'],
#  [u'varicella', 4909, 4918, 'O'],
#  [u'zoster', 4919, 4925, 'O'],
#  [u'virus', 4926, 4931, 'O'],
#  [u'VZV', 4933, 4936, 'O'],
#  [u'and', 4939, 4942, 'O'],
#  [u'Pneumocystis', 4944, 4956, 'O'],
#  [u'jiroveci', 4957, 4965, 'O'],
#  [u'pneumonia', 4967, 4976, 'O'],
#  [u'PCP', 4978, 4981, 'O'],
#  [u'post', 4983, 4987, 'O'],
#  [u'auto', 4988, 4992, 'O'],
#  [u'HSCT', 4993, 4997, 'O'],
#  [u'Overall', 4999, 5006, 'O'],
#  [u'312', 5008, 5011, 'O'],
#  [u'patients', 5012, 5020, 'O'],
#  [u'95', 5022, 5024, 'O'],
#  [u'received', 5027, 5035, 'O'],
#  [u'HSV', 5036, 5039, 'O'],
#  [u'and', 5040, 5043, 'O'],
#  [u'VZV', 5044, 5047, 'O'],
#  [u'prophylaxis', 5048, 5059, 'O'],
#  [u'with', 5060, 5064, 'O'],
#  [u'a', 5065, 5066, 'O'],
#  [u'median', 5067, 5073, 'O'],
#  [u'duration', 5074, 5082, 'O'],
#  [u'of', 5083, 5085, 'O'],
#  [u'11', 5086, 5088, 'O'],
#  [u'1', 5089, 5090, 'O'],
#  [u'months', 5091, 5097, 'O'],
#  [u'range', 5099, 5104, 'O'],
#  [u'0', 5106, 5107, 'O'],
#  [u'20', 5108, 5110, 'O'],
#  [u'and', 5112, 5115, 'O'],
#  [u'319', 5116, 5119, 'O'],
#  [u'patients', 5120, 5128, 'O'],
#  [u'98', 5130, 5132, 'O'],
#  [u'received', 5135, 5143, 'O'],
#  [u'PCP', 5144, 5147, 'O'],
#  [u'prophylaxis', 5148, 5159, 'O'],
#  [u'with', 5160, 5164, 'O'],
#  [u'a', 5165, 5166, 'O'],
#  [u'median', 5167, 5173, 'O'],
#  [u'duration', 5174, 5182, 'O'],
#  [u'of', 5183, 5185, 'O'],
#  [u'6', 5186, 5187, 'O'],
#  [u'5', 5188, 5189, 'O'],
#  [u'months', 5190, 5196, 'O'],
#  [u'range', 5198, 5203, 'O'],
#  [u'0', 5205, 5206, 'O'],
#  [u'20', 5207, 5209, 'O'],
#  [u'Experience', 5218, 5228, 'O'],
#  [u'in', 5229, 5231, 'O'],
#  [u'Systemic', 5232, 5240, 'O'],
#  [u'Anaplastic', 5241, 5251, 'O'],
#  [u'Large', 5252, 5257, 'O'],
#  [u'Cell', 5258, 5262, 'O'],
#  [u'Lymphoma', 5263, 5271, 'O'],
#  [u'Summary', 5282, 5289, 'O'],
#  [u'of', 5290, 5292, 'O'],
#  [u'Clinical', 5293, 5301, 'O'],
#  [u'Trial', 5302, 5307, 'O'],
#  [u'Experience', 5308, 5318, 'O'],
#  [u'in', 5319, 5321, 'O'],
#  [u'Relapsed', 5322, 5330, 'O'],
#  [u'sALCL', 5331, 5336, 'O'],
#  [u'Study', 5338, 5343, 'O'],
#  [u'2', 5344, 5345, 'O'],
#  [u'ADCETRIS', 5355, 5363, 'O'],
#  [u'was', 5364, 5367, 'O'],
#  [u'studied', 5368, 5375, 'O'],
#  [u'in', 5376, 5378, 'O'],
#  [u'58', 5379, 5381, 'O'],
#  [u'patients', 5382, 5390, 'O'],
#  [u'with', 5391, 5395, 'O'],
#  [u'sALCL', 5396, 5401, 'O'],
#  [u'in', 5402, 5404, 'O'],
#  [u'a', 5405, 5406, 'O'],
#  [u'single', 5407, 5413, 'O'],
#  [u'arm', 5414, 5417, 'O'],
#  [u'clinical', 5418, 5426, 'O'],
#  [u'trial', 5427, 5432, 'O'],
#  [u'in', 5433, 5435, 'O'],
#  [u'which', 5436, 5441, 'O'],
#  [u'the', 5442, 5445, 'O'],
#  [u'recommended', 5446, 5457, 'O'],
#  [u'starting', 5458, 5466, 'O'],
#  [u'dose', 5467, 5471, 'O'],
#  [u'and', 5472, 5475, 'O'],
#  [u'schedule', 5476, 5484, 'O'],
#  [u'was', 5485, 5488, 'O'],
#  [u'1', 5489, 5490, 'O'],
#  [u'8', 5491, 5492, 'O'],
#  [u'mg', 5493, 5495, 'O'],
#  [u'kg', 5496, 5498, 'O'],
#  [u'intravenously', 5499, 5512, 'O'],
#  [u'every', 5513, 5518, 'O'],
#  [u'3', 5519, 5520, 'O'],
#  [u'weeks', 5521, 5526, 'O'],
#  [u'Median', 5528, 5534, 'O'],
#  [u'duration', 5535, 5543, 'O'],
#  [u'of', 5544, 5546, 'O'],
#  [u'treatment', 5547, 5556, 'O'],
#  [u'was', 5557, 5560, 'O'],
#  [u'7', 5561, 5562, 'O'],
#  [u'cycles', 5563, 5569, 'O'],
#  [u'range', 5571, 5576, 'O'],
#  [u'1', 5578, 5579, 'O'],
#  [u'16', 5580, 5582, 'O'],
#  [u'see', 5586, 5589, 'O'],
#  [u'Clinical', 5591, 5599, 'O'],
#  [u'Studies', 5600, 5607, 'O'],
#  [u'14', 5617, 5619, 'O'],
#  [u'2', 5620, 5621, 'O'],
#  [u'The', 5641, 5644, 'O'],
#  [u'most', 5645, 5649, 'O'],
#  [u'common', 5650, 5656, 'O'],
#  [u'adverse', 5657, 5664, 'O'],
#  [u'reactions', 5665, 5674, 'O'],
#  [u'20', 5678, 5680, 'O'],
#  [u'regardless', 5684, 5694, 'O'],
#  [u'of', 5695, 5697, 'O'],
#  [u'causality', 5698, 5707, 'O'],
#  [u'were', 5709, 5713, 'O'],
#  [u'neutropenia', 5714, 5725, 'O'],
#  [u'anemia', 5727, 5733, 'O'],
#  [u'peripheral', 5735, 5745, 'O'],
#  [u'sensory', 5746, 5753, 'O'],
#  [u'neuropathy', 5754, 5764, 'O'],
#  [u'fatigue', 5766, 5773, 'O'],
#  [u'nausea', 5775, 5781, 'O'],
#  [u'pyrexia', 5783, 5790, 'O'],
#  [u'rash', 5792, 5796, 'O'],
#  [u'diarrhea', 5798, 5806, 'O'],
#  [u'and', 5808, 5811, 'O'],
#  [u'pain', 5812, 5816, 'O'],
#  [u'Table', 5822, 5827, 'O'],
#  [u'2', 5828, 5829, 'O'],
#  [u'Most', 5831, 5835, 'O'],
#  [u'Commonly', 5836, 5844, 'O'],
#  [u'Reported', 5845, 5853, 'O'],
#  [u'10', 5857, 5859, 'O'],
#  [u'Adverse', 5862, 5869, 'O'],
#  [u'Reactions', 5870, 5879, 'O'],
#  [u'in', 5880, 5882, 'O'],
#  [u'Studies', 5883, 5890, 'O'],
#  [u'1', 5891, 5892, 'O'],
#  [u'and', 5893, 5896, 'O'],
#  [u'2', 5897, 5898, 'O'],
#  [u'Classical', 5949, 5958, 'O'],
#  [u'HL', 5959, 5961, 'O'],
#  [u'sALCL', 5963, 5968, 'O'],
#  [u'Total', 6025, 6030, 'O'],
#  [u'N', 6031, 6032, 'O'],
#  [u'102', 6035, 6038, 'O'],
#  [u'of', 6040, 6042, 'O'],
#  [u'patients', 6043, 6051, 'O'],
#  [u'Total', 6053, 6058, 'O'],
#  [u'N', 6059, 6060, 'O'],
#  [u'58', 6063, 6065, 'O'],
#  [u'of', 6067, 6069, 'O'],
#  [u'patients', 6070, 6078, 'O'],
#  [u'Adverse', 6083, 6090, 'O'],
#  [u'Reaction', 6091, 6099, 'O'],
#  [u'AnyGrade', 6131, 6139, 'O'],
#  [u'Grade3', 6142, 6148, 'O'],
#  [u'Grade4', 6153, 6159, 'O'],
#  [u'AnyGrade', 6164, 6172, 'O'],
#  [u'Grade3', 6175, 6181, 'O'],
#  [u'Grade4', 6186, 6192, 'O'],
#  [u'Blood', 6202, 6207, 'O'],
#  [u'and', 6208, 6211, 'O'],
#  [u'lymphatic', 6212, 6221, 'O'],
#  [u'system', 6222, 6228, 'O'],
#  [u'disorders', 6229, 6238, 'O'],
#  [u'Neutropenia', 6321, 6332, 'O'],
#  [u'54', 6365, 6367, 'O'],
#  [u'15', 6376, 6378, 'O'],
#  [u'6', 6387, 6388, 'O'],
#  [u'55', 6398, 6400, 'O'],
#  [u'12', 6409, 6411, 'O'],
#  [u'9', 6420, 6421, 'O'],
#  [u'Anemia', 6438, 6444, 'O'],
#  [u'33', 6482, 6484, 'O'],
#  [u'8', 6493, 6494, 'O'],
#  [u'2', 6504, 6505, 'O'],
#  [u'52', 6515, 6517, 'O'],
#  [u'2', 6526, 6527, 'O'],
#  [u'Thrombocytopenia', 6555, 6571, 'O'],
#  [u'28', 6599, 6601, 'O'],
#  [u'7', 6610, 6611, 'O'],
#  [u'2', 6621, 6622, 'O'],
#  [u'16', 6632, 6634, 'O'],
#  [u'5', 6643, 6644, 'O'],
#  [u'5', 6654, 6655, 'O'],
#  [u'Lymphadenopathy', 6672, 6687, 'O'],
#  [u'11', 6716, 6718, 'O'],
#  [u'10', 6749, 6751, 'O'],
#  [u'Nervous', 6787, 6794, 'O'],
#  [u'system', 6795, 6801, 'O'],
#  [u'disorders', 6802, 6811, 'O'],
#  [u'Peripheral', 6906, 6916, 'O'],
#  [u'sensory', 6917, 6924, 'O'],
#  [u'neuropathy', 6925, 6935, 'O'],
#  [u'52', 6950, 6952, 'O'],
#  [u'8', 6961, 6962, 'O'],
#  [u'53', 6983, 6985, 'O'],
#  [u'10', 6994, 6996, 'O'],
#  [u'Peripheral', 7023, 7033, 'O'],
#  [u'motor', 7034, 7039, 'O'],
#  [u'neuropathy', 7040, 7050, 'O'],
#  [u'16', 7067, 7069, 'O'],
#  [u'4', 7078, 7079, 'O'],
#  [u'7', 7100, 7101, 'O'],
#  [u'3', 7111, 7112, 'O'],
#  [u'Headache', 7140, 7148, 'O'],
#  [u'19', 7184, 7186, 'O'],
#  [u'16', 7217, 7219, 'O'],
#  [u'2', 7228, 7229, 'O'],
#  [u'Dizziness', 7257, 7266, 'O'],
#  [u'11', 7301, 7303, 'O'],
#  [u'16', 7334, 7336, 'O'],
#  [u'General', 7372, 7379, 'O'],
#  [u'disorders', 7380, 7389, 'O'],
#  [u'and', 7390, 7393, 'O'],
#  [u'administration', 7394, 7408, 'O'],
#  [u'site', 7409, 7413, 'O'],
#  [u'conditions', 7414, 7424, 'O'],
#  [u'Fatigue', 7501, 7508, 'O'],
#  [u'49', 7545, 7547, 'O'],
#  [u'3', 7556, 7557, 'O'],
#  [u'41', 7578, 7580, 'O'],
#  [u'2', 7589, 7590, 'O'],
#  [u'2', 7600, 7601, 'O'],
#  [u'Pyrexia', 7618, 7625, 'O'],
#  [u'29', 7662, 7664, 'O'],
#  [u'2', 7673, 7674, 'O'],
#  [u'38', 7695, 7697, 'O'],
#  [u'2', 7706, 7707, 'O'],
#  [u'Chills', 7735, 7741, 'O'],
#  [u'13', 7779, 7781, 'O'],
#  [u'12', 7812, 7814, 'O'],
#  [u'Pain', 7852, 7856, 'O'],
#  [u'7', 7896, 7897, 'O'],
#  [u'28', 7929, 7931, 'O'],
#  [u'5', 7951, 7952, 'O'],
#  [u'Edema', 7969, 7974, 'O'],
#  [u'peripheral', 7975, 7985, 'O'],
#  [u'4', 8013, 8014, 'O'],
#  [u'16', 8046, 8048, 'O'],
#  [u'Infections', 8084, 8094, 'O'],
#  [u'and', 8095, 8098, 'O'],
#  [u'infestations', 8099, 8111, 'O'],
#  [u'Upper', 8203, 8208, 'O'],
#  [u'respiratory', 8209, 8220, 'O'],
#  [u'tract', 8221, 8226, 'O'],
#  [u'infection', 8227, 8236, 'O'],
#  [u'47', 8247, 8249, 'O'],
#  [u'12', 8280, 8282, 'O'],
#  [u'Gastrointestinal', 8318, 8334, 'O'],
#  [u'disorders', 8335, 8344, 'O'],
#  [u'Nausea', 8437, 8443, 'O'],
#  [u'42', 8481, 8483, 'O'],
#  [u'38', 8514, 8516, 'O'],
#  [u'2', 8525, 8526, 'O'],
#  [u'Diarrhea', 8554, 8562, 'O'],
#  [u'36', 8598, 8600, 'O'],
#  [u'1', 8609, 8610, 'O'],
#  [u'29', 8631, 8633, 'O'],
#  [u'3', 8642, 8643, 'O'],
#  [u'Abdominal', 8671, 8680, 'O'],
#  [u'pain', 8681, 8685, 'O'],
#  [u'25', 8715, 8717, 'O'],
#  [u'2', 8726, 8727, 'O'],
#  [u'1', 8737, 8738, 'O'],
#  [u'9', 8748, 8749, 'O'],
#  [u'2', 8759, 8760, 'O'],
#  [u'Vomiting', 8788, 8796, 'O'],
#  [u'22', 8832, 8834, 'O'],
#  [u'17', 8865, 8867, 'O'],
#  [u'3', 8876, 8877, 'O'],
#  [u'Constipation', 8905, 8917, 'O'],
#  [u'16', 8949, 8951, 'O'],
#  [u'19', 8982, 8984, 'O'],
#  [u'2', 8993, 8994, 'O'],
#  [u'Skin', 9020, 9024, 'O'],
#  [u'and', 9025, 9028, 'O'],
#  [u'subcutaneous', 9029, 9041, 'O'],
#  [u'tissue', 9042, 9048, 'O'],
#  [u'disorders', 9049, 9058, 'O'],
#  [u'Rash', 9139, 9143, 'O'],
#  [u'27', 9183, 9185, 'O'],
#  [u'31', 9216, 9218, 'O'],
#  [u'Pruritus', 9256, 9264, 'O'],
#  [u'17', 9300, 9302, 'O'],
#  [u'19', 9333, 9335, 'O'],
#  [u'Alopecia', 9373, 9381, 'O'],
#  [u'13', 9417, 9419, 'O'],
#  [u'14', 9450, 9452, 'O'],
#  [u'Night', 9490, 9495, 'O'],
#  [u'sweats', 9496, 9502, 'O'],
#  [u'12', 9534, 9536, 'O'],
#  [u'9', 9567, 9568, 'O'],
#  [u'Dry', 9607, 9610, 'O'],
#  [u'skin', 9611, 9615, 'O'],
#  [u'4', 9651, 9652, 'O'],
#  [u'10', 9684, 9686, 'O'],
#  [u'Respiratory', 9722, 9733, 'O'],
#  [u'thoracic', 9735, 9743, 'O'],
#  [u'and', 9744, 9747, 'O'],
#  [u'mediastinal', 9748, 9759, 'O'],
#  [u'disorders', 9760, 9769, 'O'],
#  [u'Cough', 9846, 9851, 'O'],
#  [u'25', 9890, 9892, 'O'],
#  [u'17', 9923, 9925, 'O'],
#  [u'Dyspnea', 9963, 9970, 'O'],
#  [u'13', 10007, 10009, 'O'],
#  [u'1', 10018, 10019, 'O'],
#  [u'19', 10040, 10042, 'O'],
#  [u'2', 10051, 10052, 'O'],
#  [u'Oropharyngeal', 10080, 10093, 'O'],
#  [u'pain', 10094, 10098, 'O'],
#  [u'11', 10124, 10126, 'O'],
#  [u'9', 10157, 10158, 'O'],
#  [u'Musculoskeletal', 10195, 10210, 'O'],
#  [u'and', 10211, 10214, 'O'],
#  [u'connective', 10215, 10225, 'O'],
#  [u'tissue', 10226, 10232, 'O'],
#  [u'disorders', 10233, 10242, 'O'],
#  [u'Arthralgia', 10319, 10329, 'O'],
#  [u'19', 10363, 10365, 'O'],
#  [u'9', 10396, 10397, 'O'],
#  [u'Myalgia', 10436, 10443, 'O'],
#  ...]

# %%
for e in Y:
#         print e, e['start']
    start = int(e['start'])
    end = start + int(e['len'])
    out.append([e['text'], e['type']])
# Out:
# u'of'

# %%
Y[:10]
# Out:
# [{'id': u'M1',
#   'len': u'21',
#   'section': u'S1',
#   'start': u'156',
#   'text': u'Peripheral Neuropathy',
#   'type': u'AdverseReaction'},
#  {'id': u'M2',
#   'len': u'11',
#   'section': u'S1',
#   'start': u'236',
#   'text': u'Anaphylaxis',
#   'type': u'AdverseReaction'},
#  {'id': u'M3',
#   'len': u'18',
#   'section': u'S1',
#   'start': u'252',
#   'text': u'Infusion Reactions',
#   'type': u'AdverseReaction'},
#  {'id': u'M4',
#   'len': u'22',
#   'section': u'S1',
#   'start': u'329',
#   'text': u'Hematologic Toxicities',
#   'type': u'AdverseReaction'},
#  {'id': u'M5',
#   'len': u'7',
#   'section': u'S1',
#   'start': u'410',
#   'text': u'Serious',
#   'type': u'Severity'},
#  {'id': u'M6',
#   'len': u'10',
#   'section': u'S1',
#   'start': u'418',
#   'text': u'Infections',
#   'type': u'AdverseReaction'},
#  {'id': u'M7',
#   'len': u'24',
#   'section': u'S1',
#   'start': u'433',
#   'text': u'Opportunistic Infections',
#   'type': u'AdverseReaction'},
#  {'id': u'M8',
#   'len': u'20',
#   'section': u'S1',
#   'start': u'516',
#   'text': u'Tumor Lysis Syndrome',
#   'type': u'AdverseReaction'},
#  {'id': u'M9',
#   'len': u'18',
#   'section': u'S1',
#   'start': u'595',
#   'text': u'Increased Toxicity',
#   'type': u'AdverseReaction'},
#  {'id': u'M10',
#   'len': u'18',
#   'section': u'S1',
#   'start': u'715',
#   'text': u'Increased Toxicity',
#   'type': u'AdverseReaction'}]

# %% [markdown]
# # try

# %%
# split into sentences and words (with the original index)
out = []
ct = 0
for f in glob.glob(path+'*.xml'):
    ct += 1
    print f
    
    X, Y = parse_xml(f)
    sent = [s for s in X['S1'].split('\n') if s]
    print len(sent)
#     print sent[:5]
#     for s in sent:
#         if s: print s
#     for text in X:
        
#     for e in Y:
# #         print e, e['start']
#         try:
#             start = int(e['start'])
#             end = start + int(e['len'])
#             out.append([e['text'], e['type']])
#         except:
#             pass
        
    if ct > 0: break
        
# out
# Out:
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ADCETRIS.xml
# 157

# %%
a = X['S1']
a = a.sub()
matches = [(m.group(0), m.start(), m.end(), ) for m in re.finditer(r'\S+', a)]
matches
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-1dd57c1c4ae4> in <module>()
#       1 a = X['S1']
# ----> 2 a = a.sub()
#       3 matches = [(m.group(0), m.start(), m.end(), ) for m in re.finditer(r'\S+', a)]
#       4 matches
#
# AttributeError: 'unicode' object has no attribute 'sub'

# %%
# cut the sentences and words; write into a txt file
out = []
for f in glob.glob(path+'*.xml'):
    print f
    X, Y = parse_xml(f)
    for e in Y:
#         print e, e['start']
        try:
            start = int(e['start'])
            end = start + int(e['len'])
            out.append([e['text'], e['type']])
        except:
            pass
# Out:
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ADCETRIS.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ADREVIEW.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/AFINITOR.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/AMPYRA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/AMYVID.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/APTIOM.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ARCAPTA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BELEODAQ.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BENLYSTA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BEPREVE.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BESIVANCE.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BLINCYTO.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BOSULIF.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/BREO.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CARBAGLU.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CERDELGA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CHOLINE.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CIMZIA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/CLEVIPREX.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/COARTEM.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/COMETRIQ.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DALVANCE.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DATSCAN.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DIFICID.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DOTAREM.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DUAVEE.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DUREZOL.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/DYSPORT.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/EDARBI.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ELIQUIS.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ENTEREG.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/EOVIST.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ERWINAZE.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/EYLEA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FANAPT.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FARXIGA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FERRIPROX.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FIRAZYR.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/FULYZAQ.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/GADAVIST.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/GILENYA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/GILOTRIF.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/GRANIX.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/HALAVEN.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/HORIZANT.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ILARIS.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/IMBRUVICA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/INLYTA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/INTELENCE.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/INVOKANA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/JARDIANCE.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/JEVTANA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/JUBLIA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/KALBITOR.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/KALYDECO.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/KYPROLIS.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/LUMIZYME.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/MULTAQ.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NATAZIA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NESINA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NEURACEQ.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NORTHERA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/NULOJIX.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ONFI.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/OTEZLA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PICATO.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/POTIGA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PRADAXA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PRISTIQ.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PROLIA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/PROMACTA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/QUTENZA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/SAPHRIS.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/SIMPONI.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/SIRTURO.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/STENDRA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/STRIBILD.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TAFINLAR.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TANZEUM.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TECFIDERA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TEFLARO.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TIVICAY.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TOVIAZ.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TREANDA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TRULICITY.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/TUDORZA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ULESFIA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ULORIC.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/VICTRELIS.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/VIMIZIM.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/VIZAMYL.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/VORAXAZE.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/XALKORI.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/XEOMIN.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/XIAFLEX.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/XTANDI.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/YERVOY.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ZERBAXA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ZYDELIG.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ZYKADIA.xml
# /Users/jzhu/git/nlp_adversedrug/data/train_xml/ZYTIGA.xml

# %%
len(out)
# Out:
# 14644

# %%
types = [e[1] for e in out]
Counter(types)
# Out:
# Counter({u'AdverseReaction': 12792,
#          u'Animal': 44,
#          u'DrugClass': 248,
#          u'Factor': 602,
#          u'Negation': 95,
#          u'Severity': 863})

# %%
# pd.DataFrame(out).to_csv('ner_train_1.txt', index=False, header=False, sep=' ')

# %% [markdown]
# Note: not finished
# as the word index is based on original text. We cannot do this one word by one word.
# one way is to first write all words in sentences one in a line, with the index on the same line
# then use the name index from xml to relabel those types of names

# %% [markdown]
# Alternative: change the modeling code, instead of input
